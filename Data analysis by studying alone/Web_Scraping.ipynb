# %% [markdown]
# <a href="https://colab.research.google.com/github/GeekDM/Data-Analysis/blob/main/Data%20analysis%20by%20studying%20alone/Web_Scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Web Scraping**

# %%
import pandas as pd
books_df = pd.read_json('20s_best_book.json')
books_df.head()
# Out:
#    no  ranking                                        bookname  \
# 0   1        1                                소년이 온다 :한강 장편소설
# 1   2        2  물고기는 존재하지 않는다 :상실, 사랑 그리고 숨어 있는 삶의 질서에 관한 이야기
# 2   3        3                                   모순 :양귀자 장편소설
# 3   4        4                              작별하지 않는다 :한강 장편소설
# 4   5        5                             지구 끝의 온실 :김초엽 장편소설
#
#             authors            publisher  publication_year         isbn13  \
# 0           지은이: 한강                   창비              2014  9788936434120
# 1  룰루 밀러 지음 ;정지인 옮김                  곰출판              2021  9791189327156
# 2          지은이: 양귀자                   쓰다              2013  9788998441012
# 3           지은이: 한강                 문학동네              2021  9788954682152
# 4          지은이: 김초엽  Giant Books(자이언트북스)              2021  9791191824001
#
#   addition_symbol vol class_no          class_nm  loan_count  \
# 0           03810       813.62    문학 > 한국문학 > 소설         560
# 1           03400       490.99  자연과학 > 동물학 > 동물학         465
# 2           03810       813.62    문학 > 한국문학 > 소설         422
# 3           03810       813.62    문학 > 한국문학 > 소설         421
# 4           03810        813.7    문학 > 한국문학 > 소설         416
#
#                                         bookImageURL  \
# 0  http://image.aladin.co.kr/product/4086/97/cove...
# 1  https://image.aladin.co.kr/product/28465/73/co...
# 2  https://bookthumb-phinf.pstatic.net/cover/071/...
# 3  https://image.aladin.co.kr/product/27877/5/cov...
# 4  https://image.aladin.co.kr/product/27692/63/co...
#
#                                   bookDtlUrl
# 0  https://data4library.kr/bookV?seq=2037399
# 1  https://data4library.kr/bookV?seq=6360937
# 2  https://data4library.kr/bookV?seq=1938053
# 3  https://data4library.kr/bookV?seq=6086446
# 4  https://data4library.kr/bookV?seq=6065686

# %%
books = books_df[['no','ranking','bookname','authors','publisher','publication_year','isbn13']]
books.head()
# Out:
#    no  ranking                                        bookname  \
# 0   1        1                                소년이 온다 :한강 장편소설
# 1   2        2  물고기는 존재하지 않는다 :상실, 사랑 그리고 숨어 있는 삶의 질서에 관한 이야기
# 2   3        3                                   모순 :양귀자 장편소설
# 3   4        4                              작별하지 않는다 :한강 장편소설
# 4   5        5                             지구 끝의 온실 :김초엽 장편소설
#
#             authors            publisher  publication_year         isbn13
# 0           지은이: 한강                   창비              2014  9788936434120
# 1  룰루 밀러 지음 ;정지인 옮김                  곰출판              2021  9791189327156
# 2          지은이: 양귀자                   쓰다              2013  9788998441012
# 3           지은이: 한강                 문학동네              2021  9788954682152
# 4          지은이: 김초엽  Giant Books(자이언트북스)              2021  9791191824001
