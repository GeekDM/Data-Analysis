# %% [markdown]
# <a href="https://colab.research.google.com/github/GeekDM/Data-Analysis/blob/main/Data%20analysis%20by%20studying%20alone/Namsan_Library_collection_loan_list.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import gdown
import chardet

with open('/서울특별시교육청남산도서관 장서 대출목록 (2024년 12월).csv', mode='rb') as f:
  d = f.readline()
print(chardet.detect(d))
# Out:
# {'encoding': 'EUC-KR', 'confidence': 0.99, 'language': 'Korean'}

# %%
with open('/서울특별시교육청남산도서관 장서 대출목록 (2024년 12월).csv', encoding='EUC-KR') as f:
  print(f.readline())
  print(f.readline())
# Out:
# 번호,도서명,저자,출판사,발행년도,ISBN,세트 ISBN,부가기호,권,주제분류번호,도서권수,대출건수,등록일자,
#
# "1","一千?? =a thousand blue ","[?]千先? 著  ;胡椒筒 ?","時報","2023","9786263538610","","","","813.7","1","0","2024-12-19",

# %%
import pandas as pd

df = pd.read_csv('/서울특별시교육청남산도서관 장서 대출목록 (2024년 12월).csv', encoding='EUC-KR', low_memory=False)
## df = pd.read_csv('/서울특별시교육청남산도서관 장서 대출목록 (2024년 12월).csv', encoding='EUC-KR', dtype={'ISBN': str, '세트 ISBN': str, '주제분류번호': str})

df.head()
# Out:
#    번호                                                도서명  \
# 0   1                             一千?? =a thousand blue
# 1   2                                           地球??的?室
# 2   3                                       ボンジュ?ル,トゥ?ル
# 3   4                                              明るい夜
# 4   5  はちどり =House of Hummingbird :1994年、閉ざされることのない記憶...
#
#                         저자          출판사  발행년도           ISBN  세트 ISBN 부가기호  \
# 0         [?]千先? 著  ;胡椒筒 ?           時報  2023  9786263538610      NaN  NaN
# 1          [?]金草? 著 ;胡椒筒 ?  廣東花城出版社有限公司  2023  9787536099760      NaN  NaN
# 2  ハンユンソブ 著 ;キムジナ ? ;?華順 ?          影書房  2024  9784877144999      NaN  NaN
# 3        チェ·ウニョン 著 ;古川綾子 ?         ?紀書房  2023  9784750517803      NaN  NaN
# 4          キム·ボラ 著 ;根本理? ?       オ?クラ出版  2023  9784775530115      NaN  NaN
#
#      권 주제분류번호  도서권수  대출건수        등록일자  Unnamed: 13
# 0  NaN  813.7     1     0  2024-12-19          NaN
# 1  NaN  813.7     1     0  2024-12-19          NaN
# ...

# %%
df.to_csv('ns_202412.csv')

# %%
with open('ns_202412.csv') as f:
  for i in range(3):
    print(f.readline(), end='')

ns_df = pd.read_csv('ns_202412.csv', low_memory=False)
ns_df.head()
# Out:
# ,번호,도서명,저자,출판사,발행년도,ISBN,세트 ISBN,부가기호,권,주제분류번호,도서권수,대출건수,등록일자,Unnamed: 13
# 0,1,一千?? =a thousand blue ,[?]千先? 著  ;胡椒筒 ?,時報,2023,9786263538610,,,,813.7,1,0,2024-12-19,
# 1,2,地球??的?室 ,[?]金草? 著 ;胡椒筒 ?,廣東花城出版社有限公司,2023,9787536099760,,,,813.7,1,0,2024-12-19,
#    Unnamed: 0  번호                                                도서명  \
# 0           0   1                             一千?? =a thousand blue
# 1           1   2                                           地球??的?室
# 2           2   3                                       ボンジュ?ル,トゥ?ル
# 3           3   4                                              明るい夜
# 4           4   5  はちどり =House of Hummingbird :1994年、閉ざされることのない記憶...
#
#                         저자          출판사  발행년도           ISBN  세트 ISBN 부가기호  \
# 0         [?]千先? 著  ;胡椒筒 ?           時報  2023  9786263538610      NaN  NaN
# 1          [?]金草? 著 ;胡椒筒 ?  廣東花城出版社有限公司  2023  9787536099760      NaN  NaN
# 2  ハンユンソブ 著 ;キムジナ ? ;?華順 ?          影書房  2024  9784877144999      NaN  NaN
# ...

# %%
ns_df = pd.read_csv('ns_202412.csv', index_col=0, low_memory=False)
ns_df.head()
# Out:
#    번호                                                도서명  \
# 0   1                             一千?? =a thousand blue
# 1   2                                           地球??的?室
# 2   3                                       ボンジュ?ル,トゥ?ル
# 3   4                                              明るい夜
# 4   5  はちどり =House of Hummingbird :1994年、閉ざされることのない記憶...
#
#                         저자          출판사  발행년도           ISBN  세트 ISBN 부가기호  \
# 0         [?]千先? 著  ;胡椒筒 ?           時報  2023  9786263538610      NaN  NaN
# 1          [?]金草? 著 ;胡椒筒 ?  廣東花城出版社有限公司  2023  9787536099760      NaN  NaN
# 2  ハンユンソブ 著 ;キムジナ ? ;?華順 ?          影書房  2024  9784877144999      NaN  NaN
# 3        チェ·ウニョン 著 ;古川綾子 ?         ?紀書房  2023  9784750517803      NaN  NaN
# 4          キム·ボラ 著 ;根本理? ?       オ?クラ出版  2023  9784775530115      NaN  NaN
#
#      권 주제분류번호  도서권수  대출건수        등록일자  Unnamed: 13
# 0  NaN  813.7     1     0  2024-12-19          NaN
# 1  NaN  813.7     1     0  2024-12-19          NaN
# ...

# %%
df.to_csv('ns_202412.csv', index=False)
