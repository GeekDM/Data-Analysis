# %% [markdown]
# <a href="https://colab.research.google.com/github/GeekDM/Data-Analysis/blob/main/Data%20analysis%20by%20studying%20alone/API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **JSON**

# %%
d = {"name" : "혼자 공부하는 데이터 분석"}
print(d['name'])
# Out:
# 혼자 공부하는 데이터 분석

# %%
import json

d = {"name" : "혼자 공부하는 데이터 분석"}
print(d['name'])

d_str = json.dumps(d, ensure_ascii=False)
print(d_str)
# Out:
# 혼자 공부하는 데이터 분석
# {"name": "혼자 공부하는 데이터 분석"}

# %%
print(type(d_str))
# Out:
# <class 'str'>

# %%
d2 = json.loads(d_str)
print(d2['name'])
# Out:
# 혼자 공부하는 데이터 분석

# %%
print(type(d2))
# Out:
# <class 'dict'>

# %%
d3 = json.loads('{"name": "혼자 공부하는 데이터 분석", "author": "박해선", "year": 2022}')
print(d3['name'])
print(d3['author'])
print(d3['year'])
# Out:
# 혼자 공부하는 데이터 분석
# 박해선
# 2022

# %%
d3 = json.loads('{"name": "혼자 공부하는 데이터 분석", "author": ["박해선", "홍길동"], "year": 2022}')
print(d3['author'][1])
# Out:
# 홍길동

# %%
d4_str = """
[
  {"name": "혼자 공부하는 데이터 분석", "author": "박해선", "year": 2022},
  {"name": "혼자 공부하는 머신러닝+딥러닝", "author": "박해선", "year": 2020}
]
"""
d4 = json.loads(d4_str)
print(d4[0]['name'])
# Out:
# 혼자 공부하는 데이터 분석

# %%
import pandas as pd
pd.read_json(d4_str)
# Out:
# <ipython-input-18-84823bfe0278>:2: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   pd.read_json(d4_str)
#                name author  year
# 0    혼자 공부하는 데이터 분석    박해선  2022
# 1  혼자 공부하는 머신러닝+딥러닝    박해선  2020

# %%
pd.DataFrame(d4)
# Out:
#                name author  year
# 0    혼자 공부하는 데이터 분석    박해선  2022
# 1  혼자 공부하는 머신러닝+딥러닝    박해선  2020

# %% [markdown]
# **XML**

# %%
x_str = """
<book>
  <name>혼자 공부하는 데이터 분석</name>
  <author>박해선</author>
  <year>2022</year>
</book>
"""

# %%
import xml.etree.ElementTree as et
book = et.fromstring(x_str)

# %%
print(type(book))
# Out:
# <class 'xml.etree.ElementTree.Element'>

# %%
print(book.tag)
# Out:
# book

# %%
book_childs = list(book)
print(book_childs)
# Out:
# [<Element 'name' at 0x7b9e9444b6a0>, <Element 'author' at 0x7b9e9444b6f0>, <Element 'year' at 0x7b9e9444b740>]

# %%
name, author, year = book_childs
print(name.text)
print(author.text)
print(year.text)
# Out:
# 혼자 공부하는 데이터 분석
# 박해선
# 2022

# %%
name = book.findtext('name')
author = book.findtext('author')
year = book.findtext('year')
print(name)
print(author)
print(year)
# Out:
# 혼자 공부하는 데이터 분석
# 박해선
# 2022

# %%
x2_str = """
<books>
  <book>
    <name>혼자 공부하는 데이터 분석</name>
    <author>박해선</author>
    <year>2022</year>
  </book>
  <book>
    <name>혼자 공부하는 머신러닝+딥러닝</name>
    <author>박해선</author>
    <year>2020</year>
  </book>
</books>
"""

# %%
books = et.fromstring(x2_str)
print(books.tag)
# Out:
# books

# %%
for book in books.findall('book'):
  name = book.findtext('name')
  author = book.findtext('author')
  year = book.findtext('year')
  print(name)
  print(author)
  print(year)
  print()
# Out:
# 혼자 공부하는 데이터 분석
# 박해선
# 2022
#
# 혼자 공부하는 머신러닝+딥러닝
# 박해선
# 2020

# %%
pd.read_xml(x2_str)
# Out:
# <ipython-input-30-b21008a18b01>:1: FutureWarning: Passing literal xml to 'read_xml' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   pd.read_xml(x2_str)
#                name author  year
# 0    혼자 공부하는 데이터 분석    박해선  2022
# 1  혼자 공부하는 머신러닝+딥러닝    박해선  2020

# %% [markdown]
# **API**
#
# - HTTP GET
# -> http://data4library.kr/api/loanItemSrch?startDt=2024-12-01&endDt=2024-12-31
#    *(call address)* ? *(parameter)* = *(value)* & *(parameter)* = *(value)*

# %%
import requests

# %%
url = "http://data4library.kr/api/loanItemSrch?format=json&startDt=2024-12-01&endDt=2024-12-31&age=20&authKey=c7b74fafc12bb682a7debd618913f45daeb3e14ef62920bfacdbd584e1cc5cc8"

# %%
r = requests.get(url)

# %%
data = r.json()
print(data)
# Out:
# {'response': {'request': {'startDt': '2024-12-01', 'endDt': '2024-12-31', 'age': '20', 'pageNo': 1, 'pageSize': 200}, 'resultNum': 200, 'numFound': 5000, 'docs': [{'doc': {'no': 1, 'ranking': '1', 'bookname': '소년이 온다 :한강 장편소설 ', 'authors': '지은이: 한강', 'publisher': '창비', 'publication_year': '2014', 'isbn13': '9788936434120', 'addition_symbol': '03810', 'vol': '', 'class_no': '813.62', 'class_nm': '문학 > 한국문학 > 소설', 'loan_count': '560', 'bookImageURL': 'http://image.aladin.co.kr/product/4086/97/cover/8936434128_2.jpg', 'bookDtlUrl': 'https://data4library.kr/bookV?seq=2037399'}}, {'doc': {'no': 2, 'ranking': '2', 'bookname': '물고기는 존재하지 않는다 :상실, 사랑 그리고 숨어 있는 삶의 질서에 관한 이야기 ', 'authors': '룰루 밀러 지음 ;정지인 옮김', 'publisher': '곰출판', 'publication_year': '2021', 'isbn13': '9791189327156', 'addition_symbol': '03400', 'vol': '', 'class_no': '490.99', 'class_nm': '자연과학 > 동물학 > 동물학', 'loan_count': '465', 'bookImageURL': 'https://image.aladin.co.kr/product/28465/73/cover/k092835920_1.jpg', 'bookDtlUrl': 'https://data4library.kr/bookV?seq=6360937'}}, {'doc': {'no': 3, 'ranking': '3', 'bookname': '모순 :양귀자 장편소설 ', 'authors': '지은이: 양귀자', 'publisher': '쓰다', 'publication_year': '2013', 'isbn13': '9788998441012', 'addition_symbol': '03810', 'vol': '', 'class_no': '813.62', 'class_nm': '문학 > 한국문학 > 소설', 'loan_count': '422', 'bookImageURL': 'https://bookthumb-phinf.pstatic.net/cover/071/902/07190270.jpg?type=m1&udate=20170801', 'bookDtlUrl': 'https://data4library.kr/bookV?seq=1938053'}}, {'doc': {'no': 4, 'ranking': '4', 'bookname': '작별하지 않는다 :한강 장편소설 ', 'authors': '지은이: 한강', 'publisher': '문학동네', 'publication_year': '2021', 'isbn13': '9788954682152', 'addition_symbol': '03810', 'vol': '', 'class_no': '813.62', 'class_nm': '문학 > 한국문학 > 소설', 'loan_count': '421', 'bookImageURL': 'https://image.aladin.co.kr/product/27877/5/cover/8954682154_1.jpg', 'bookDtlUrl': 'https://data4library.kr/bookV?seq=6086446'}}, {'doc': {'no': 5, 'ranking': '5', 'bookname': '지구 끝의 온실 :김초엽 장편소설 ', 'authors': '지은이: 김초엽', 'publisher': 'Giant Books(자이언트북스)', 'publication_year': '2021', 'isbn13': '9791191824001', 'addition_symbol': '03810', 'vol': '', 'class_no': '813.7', 'class_nm': '문학 > 한국문학 > 소설', 'loan_count': '416', 'bookImageURL': 'https://image.aladin.co.kr/product/27692/63/cover/k082733434_1.jpg', 'bookDtlUrl': 'https://data4library.kr/bookV?seq=6065686'}}, {'doc': {'no': 6, 'ranking': '6', 'bookname': '채식주의자:한강 연작소설', 'authors': '한강', 'publisher': '창비', 'publication_year': '2007', 'isbn13': '9788936433598', 'addition_symbol': '03810', 'vol': '', 'class_no': '813.6', 'class_nm': '문학 > 한국문학 > 소설', 'loan_count': '399', 'bookImageURL': 'https://bookthumb-phinf.pstatic.net/cover/033/094/03309417.jpg?type=m1&udate=20180609', 'bookDtlUrl': 'https://data4library.kr/bookV?seq=2155671'}}, {'doc': {'no': 7, 'ranking': '7', 'bookname': '나는 소망한다 내게 금지된 것을 :양귀자 장편소설 ', 'authors': '지은이: 양귀자', 'publisher': '쓰다', 'publication_year': '2019', 'isbn13': '9788998441074', 'addition_symbol': '03810', 'vol': '', 'class_no': '813.62', 'class_nm': '문학 > 한국문학 > 소설', 'loan_count': '374', 'bookImageURL': 'https://image.aladin.co.kr/product/18936/52/cover/8998441071_1.jpg', 'bookDtlUrl': 'https://data4library.kr/bookV?seq=5395822'}}, {'doc': {'no': 8, 'ranking': '8', 'bookname': '홍학의 자리 :정해연 장편소설 ', 'authors': '지은이: 정해연', 'publisher': '문학동네', 'publication_year': '2021', 'isbn13': '9788954681155', 'addition_symbol': '03810', 'vol': '', 'class_no': '813.7', 'class_nm': '문학 > 한국문학 > 소설', 'loan_count': '355', 'bookImageURL': 'https://image.aladin.co.kr/product/27587/94/cover/8954681158_1.jpg', 'bookDtlUrl': 'https://data4library.kr/bookV?seq=6050062'}}, {'doc': {'no': 9, 'ranking': '9', 'bookname': '종의 기원 =정유정 장편소설 /The origin of species ', 'authors': '지은이: 정유정', 'publisher': '은행나무', 'publication_year': '2016', 'isbn13': '9788956609959', 'addition_symbol': '03810', 'vol': '', 'class_no': '813.7', 'class_nm': '문학 > 한국문학 > 소설', 'loan_count': '354', 'bookImageURL': 'http://image.aladin.co.kr/product/7492/9/cover/ ...

# %%
data
# Out:
# {'response': {'request': {'startDt': '2024-12-01',
#    'endDt': '2024-12-31',
#    'age': '20',
#    'pageNo': 1,
#    'pageSize': 200},
#   'resultNum': 200,
#   'numFound': 5000,
#   'docs': [{'doc': {'no': 1,
#      'ranking': '1',
#      'bookname': '소년이 온다 :한강 장편소설 ',
#      'authors': '지은이: 한강',
#      'publisher': '창비',
#      'publication_year': '2014',
#      'isbn13': '9788936434120',
#      'addition_symbol': '03810',
#      'vol': '',
#      'class_no': '813.62',
#      'class_nm': '문학 > 한국문학 > 소설',
#      'loan_count': '560',
#      'bookImageURL': 'http://image.aladin.co.kr/product/4086/97/cover/8936434128_2.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=2037399'}},
#    {'doc': {'no': 2,
#      'ranking': '2',
#      'bookname': '물고기는 존재하지 않는다 :상실, 사랑 그리고 숨어 있는 삶의 질서에 관한 이야기 ',
#      'authors': '룰루 밀러 지음 ;정지인 옮김',
#      'publisher': '곰출판',
#      'publication_year': '2021',
#      'isbn13': '9791189327156',
#      'addition_symbol': '03400',
#      'vol': '',
#      'class_no': '490.99',
#      'class_nm': '자연과학 > 동물학 > 동물학',
#      'loan_count': '465',
#      'bookImageURL': 'https://image.aladin.co.kr/product/28465/73/cover/k092835920_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=6360937'}},
#    {'doc': {'no': 3,
#      'ranking': '3',
#      'bookname': '모순 :양귀자 장편소설 ',
#      'authors': '지은이: 양귀자',
#      'publisher': '쓰다',
#      'publication_year': '2013',
#      'isbn13': '9788998441012',
#      'addition_symbol': '03810',
#      'vol': '',
#      'class_no': '813.62',
#      'class_nm': '문학 > 한국문학 > 소설',
#      'loan_count': '422',
#      'bookImageURL': 'https://bookthumb-phinf.pstatic.net/cover/071/902/07190270.jpg?type=m1&udate=20170801',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=1938053'}},
#    {'doc': {'no': 4,
#      'ranking': '4',
#      'bookname': '작별하지 않는다 :한강 장편소설 ',
#      'authors': '지은이: 한강',
#      'publisher': '문학동네',
#      'publication_year': '2021',
#      'isbn13': '9788954682152',
#      'addition_symbol': '03810',
#      'vol': '',
#      'class_no': '813.62',
#      'class_nm': '문학 > 한국문학 > 소설',
#      'loan_count': '421',
#      'bookImageURL': 'https://image.aladin.co.kr/product/27877/5/cover/8954682154_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=6086446'}},
#    {'doc': {'no': 5,
#      'ranking': '5',
#      'bookname': '지구 끝의 온실 :김초엽 장편소설 ',
#      'authors': '지은이: 김초엽',
#      'publisher': 'Giant Books(자이언트북스)',
#      'publication_year': '2021',
#      'isbn13': '9791191824001',
#      'addition_symbol': '03810',
#      'vol': '',
#      'class_no': '813.7',
#      'class_nm': '문학 > 한국문학 > 소설',
#      'loan_count': '416',
#      'bookImageURL': 'https://image.aladin.co.kr/product/27692/63/cover/k082733434_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=6065686'}},
#    {'doc': {'no': 6,
#      'ranking': '6',
#      'bookname': '채식주의자:한강 연작소설',
#      'authors': '한강',
#      'publisher': '창비',
#      'publication_year': '2007',
#      'isbn13': '9788936433598',
#      'addition_symbol': '03810',
#      'vol': '',
#      'class_no': '813.6',
#      'class_nm': '문학 > 한국문학 > 소설',
#      'loan_count': '399',
#      'bookImageURL': 'https://bookthumb-phinf.pstatic.net/cover/033/094/03309417.jpg?type=m1&udate=20180609',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=2155671'}},
#    {'doc': {'no': 7,
#      'ranking': '7',
#      'bookname': '나는 소망한다 내게 금지된 것을 :양귀자 장편소설 ',
#      'authors': '지은이: 양귀자',
#      'publisher': '쓰다',
#      'publication_year': '2019',
#      'isbn13': '9788998441074',
#      'addition_symbol': '03810',
#      'vol': '',
#      'class_no': '813.62',
#      'class_nm': '문학 > 한국문학 > 소설',
#      'loan_count': '374',
#      'bookImageURL': 'https://image.aladin.co.kr/product/18936/52/cover/8998441071_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=5395822'}},
#    {'doc': {'no': 8,
#      'ranking': '8',
#      'bookname': '홍학의 자리 :정해연 장편소설 ',
#      'authors': '지은이: 정해연',
#      'publisher': '문학동네',
#      'publication_year': '2021',
#      'isbn13': '9788954681155',
#      'addition_symbol': '03810',
#      'vol': '',
#      'class_no': '813.7',
#      'class_nm': '문학 > 한국문학 > 소설',
#      'loan_count': '355',
#      'bookImageURL': 'https://image.aladin.co.kr/product/27587/94/cover/8954681158_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=6050062'}},
#    {'doc': {'no': 9,
#      'ranking': '9',
#      'bookname': '종의 기원 =정유정 장편소설 /The origin of species ',
#      'authors': '지은이: 정유정',
#      'publisher': '은행나무',
#      'publication_year': '2016',
#      'isbn13': '9788956609959',
#      'addition_symbol': '03810',
#      'vol': '',
#      'class_no': '813.7',
#      'class_nm': '문학 > 한국문학 > 소설',
#      'loan_count': '354',
#      'bookImageURL': 'http://image.aladin.co.kr/product/7492/9/cover/8956609950_2.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=3151708'}},
#    {'doc': {'no': 10,
#      'ranking': '10',
#      'bookname': '천 개의 파랑 :천선란 장편소설 ',
#      'authors': '지은이: 천선란',
#      'publisher': '허블',
#      'publication_year': '2020',
#      'isbn13': '9791190090261',
#      'addition_symbol': '03810',
#      'vol': '',
#      'class_no': '813.7',
#      'class_nm': '문학 > 한국문학 > 소설',
#      'loan_count': '346',
#      'bookImageURL': 'https://image.aladin.co.kr/product/24895/69/cover/k882632470_2.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=5738747'}},
#    {'doc': {'no': 11,
#      'ranking': '11',
#      'bookname': '대도시의 사랑법 :박상영 연작소설 ',
#      'authors': '지은이: 박상영',
#      'publisher': '창비',
#      'publication_year': '2019',
#      'isbn13': '9788936437978',
#      'addition_symbol': '03810',
#      'vol': '',
#      'class_no': '813.7',
#      'class_nm': '문학 > 한국문학 > 소설',
#      'loan_count': '342',
#      'bookImageURL': 'https://image.aladin.co.kr/product/19543/91/cover/8936437976_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=5435897'}},
#    {'doc': {'no': 12,
#      'ranking': '12',
#      'bookname': '불편한 편의점 :김호연 장편소설 ',
#      'authors': '지은이: 김호연',
#      'publisher': '나무옆의자',
#      'publication_year': '2021',
#      'isbn13': '9791161571188',
#      'addition_symbol': '03810',
#      'vol': '',
#      'class_no': '813.7',
#      'class_nm': '문학 > 한국문학 > 소설',
#      'loan_count': '324',
#      'bookImageURL': 'https://image.aladin.co.kr/product/26942/84/cover/k582730818_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=5962217'}},
#    {'doc': {'no': 13,
#      'ranking': '13',
#      'bookname': '밝은 밤 :최은영 장편소설 ',
#      'authors': '지은이: 최은영',
#      'publisher': '문학동네',
#      'publication_year': '2021',
#      'isbn13': '9788954681179',
#      'addition_symbol': '03810',
#      'vol': '',
#      'class_no': '813.7',
#      'class_nm': '문학 > 한국문학 > 소설',
#      'loan_count': '312',
#      'bookImageURL': 'https://image.aladin.co.kr/product/27541/91/cover/8954681174_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=6045915'}},
#    {'doc': {'no': 14,
#      'ranking': '14',
#      'bookname': '바깥은 여름 :김애란 소설 ',
#      'authors': '지은이: 김애란',
#      'publisher': '문학동네',
#      'publication_year': '2017',
#      'isbn13': '9788954646079',
#      'addition_symbol': '03810',
#      'vol': '',
#      'class_no': '813.7',
#      'class_nm': '문학 > 한국문학 > 소설',
#      'loan_count': '304',
#      'bookImageURL': 'http://image.aladin.co.kr/product/15533/81/cover/k852533629_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=3451595'}},
#    {'doc': {'no': 15,
#      'ranking': '15',
#      'bookname': '지구에서 한아뿐 :정세랑 장편소설 ',
#      'authors': '지은이: 정세랑',
#      'publisher': '난다',
#      'publication_year': '2019',
#      'isbn13': '9791188862290',
#      'addition_symbol': '03810',
#      'vol': '',
#      'class_no': '813.7',
#      'class_nm': '문학 > 한국문학 > 소설',
#      'loan_count': '299',
#      'bookImageURL': 'https://image.aladin.co.kr/product/19804/82/cover/k072635131_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=5446546'}},
#    {'doc': {'no': 16,
#      'ranking': '16',
#      'bookname': '우리가 빛의 속도로 갈 수 없다면 :김초엽 소설 ',
#      'authors': '지은이: 김초엽',
#      'publisher': '허블',
#      'publication_year': '2019',
#      'isbn13': '9791190090018',
#      'addition_symbol': '03810',
#      'vol': '',
#      'class_no': '813.7',
#      'class_nm': '문학 > 한국문학 > 소설',
#      'loan_count': '290',
#      'bookImageURL': 'https://image.aladin.co.kr/product/19359/16/cover/s972635417_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=5430429'}},
#    {'doc': {'no': 17,
#      'ranking': '17',
#      'bookname': '도둑맞은 집중력 :집중력 위기의 시대, 삶의 주도권을 되찾는 법 ',
#      'authors': '요한 하리 지음 ;김하현 옮김',
#      'publisher': '어크로스(어크로스출판그룹)',
#      'publication_year': '2023',
#      'isbn13': '9791167740984',
#      'addition_symbol': '03180',
#      'vol': '',
#      'class_no': '181.27',
#      'class_nm': '철학 > 심리학 > 각론',
#      'loan_count': '288',
#      'bookImageURL': 'https://image.aladin.co.kr/product/31559/97/cover/k682832859_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=6682845'}},
#    {'doc': {'no': 18,
#      'ranking': '18',
#      'bookname': '칵테일, 러브, 좀비 ',
#      'authors': '지은이: 조예은',
#      'publisher': '안전가옥',
#      'publication_year': '2020',
#      'isbn13': '9791190174756',
#      'addition_symbol': '03810',
#      'vol': '',
#      'class_no': '813.7',
#      'class_nm': '문학 > 한국문학 > 소설',
#      'loan_count': '287',
#      'bookImageURL': 'https://image.aladin.co.kr/product/23736/85/cover/k692639764_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=5650149'}},
#    {'doc': {'no': 19,
#      'ranking': '19',
#      'bookname': '채식주의자 :한강 장편소설 ',
#      'authors': '지은이: 한강',
#      'publisher': '창비',
#      'publication_year': '2022',
#      'isbn13': '9788936434595',
#      'addition_symbol': '03810',
#      'vol': '',
#      'class_no': '813.62',
#      'class_nm': '문학 > 한국문학 > 소설',
#      'loan_count': '285',
#      'bookImageURL': 'https://image.aladin.co.kr/product/29137/2/cover/8936434594_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=6428779'}},
#    {'doc': {'no': 20,
#      'ranking': '20',
#      'bookname': '달러구트 꿈 백화점 :이미예 장편소설',
#      'authors': '지은이: 이미예',
#      'publisher': '팩토리나인',
#      'publication_year': '2020',
#      'isbn13': '9791165341909',
#      'addition_symbol': '03810',
#      'vol': '',
#      'class_no': '813.7',
#      'class_nm': '문학 > 한국문학 > 소설',
#      'loan_count': '282',
#      'bookImageURL': 'https://image.aladin.co.kr/product/24512/70/cover/k392630952_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=5707051'}},
#    {'doc': {'no': 21,
#      'ranking': '21',
#      'bookname': '돈은 좋지만 재테크는 겁나는 너에게 ',
#      'authors': '뿅글이 지음',
#      'publisher': '첨단',
#      'publication_year': '2023',
#      'isbn13': '9788960306134',
#      'addition_symbol': '03320',
#      'vol': '',
#      'class_no': '327.04',
#      'class_nm': '사회과학 > 경제학 > 금융',
#      'loan_count': '274',
#      'bookImageURL': 'https://image.aladin.co.kr/product/30921/24/cover/8960306134_2.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=6627400'}},
#    {'doc': {'no': 22,
#      'ranking': '22',
#      'bookname': '아주 희미한 빛으로도 :최은영 소설 ',
#      'authors': '지은이: 최은영',
#      'publisher': '문학동네',
#      'publication_year': '2023',
#      'isbn13': '9788954695053',
#      'addition_symbol': '03810',
#      'vol': '',
#      'class_no': '813.7',
#      'class_nm': '문학 > 한국문학 > 소설',
#      'loan_count': '271',
#      'bookImageURL': 'https://image.aladin.co.kr/product/32129/40/cover/8954695051_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=6738257'}},
#    {'doc': {'no': 23,
#      'ranking': '23',
#      'bookname': '시선으로부터, :정세랑 장편소설 ',
#      'authors': '지은이: 정세랑',
#      'publisher': '문학동네',
#      'publication_year': '2020',
#      'isbn13': '9788954672214',
#      'addition_symbol': '03810',
#      'vol': '',
#      'class_no': '813.7',
#      'class_nm': '문학 > 한국문학 > 소설',
#      'loan_count': '265',
#      'bookImageURL': 'https://image.aladin.co.kr/product/24131/37/cover/8954672213_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=5674475'}},
#    {'doc': {'no': 24,
#      'ranking': '24',
#      'bookname': '희랍어 시간 :한강 장편소설 ',
#      'authors': '지은이: 한강',
#      'publisher': '문학동네',
#      'publication_year': '2011',
#      'isbn13': '9788954616515',
#      'addition_symbol': '03810',
#      'vol': '',
#      'class_no': '813.62',
#      'class_nm': '문학 > 한국문학 > 소설',
#      'loan_count': '248',
#      'bookImageURL': 'https://bookthumb-phinf.pstatic.net/cover/067/707/06770742.jpg?type=m1&udate=20170801',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=1207905'}},
#    {'doc': {'no': 25,
#      'ranking': '25',
#      'bookname': '돌이킬 수 있는 =문목하 장편소설 /Eversible ',
#      'authors': '지은이: 문목하',
#      'publisher': '아작',
#      'publication_year': '2018',
#      'isbn13': '9791189015381',
#      'addition_symbol': '03810',
#      'vol': '',
#      'class_no': '813.7',
#      'class_nm': '문학 > 한국문학 > 소설',
#      'loan_count': '243',
#      'bookImageURL': 'https://image.aladin.co.kr/product/17531/63/cover/k062534304_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=5253241'}},
#    {'doc': {'no': 26,
#      'ranking': '25',
#      'bookname': '내가 한 말을 내가 오해하지 않기로 함 ',
#      'authors': '지은이: 문상훈',
#      'publisher': '위너스북',
#      'publication_year': '2024',
#      'isbn13': '9791189352745',
#      'addition_symbol': '03810',
#      'vol': '',
#      'class_no': '818',
#      'class_nm': '문학 > 한국문학 > 르포르타주 및 기타',
#      'loan_count': '243',
#      'bookImageURL': 'https://image.aladin.co.kr/product/33037/31/cover/k882937586_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=6806344'}},
#    {'doc': {'no': 27,
#      'ranking': '27',
#      'bookname': '구의 증명 :최진영 소설 ',
#      'authors': '지은이: 최진영',
#      'publisher': '은행나무',
#      'publication_year': '2015',
#      'isbn13': '9788956608556',
#      'addition_symbol': '03810',
#      'vol': '',
#      'class_no': '813.7',
#      'class_nm': '문학 > 한국문학 > 소설',
#      'loan_count': '242',
#      'bookImageURL': 'http://image.aladin.co.kr/product/5527/50/cover/8956608555_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=2619618'}},
#    {'doc': {'no': 28,
#      'ranking': '28',
#      'bookname': '급류 :정대건 장편소설 ',
#      'authors': '지은이: 정대건',
#      'publisher': '민음사',
#      'publication_year': '2022',
#      'isbn13': '9788937473401',
#      'addition_symbol': '04810',
#      'vol': '',
#      'class_no': '813.7',
#      'class_nm': '문학 > 한국문학 > 소설',
#      'loan_count': '240',
#      'bookImageURL': 'https://image.aladin.co.kr/product/30769/24/cover/8937473402_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=6614564'}},
#    {'doc': {'no': 29,
#      'ranking': '29',
#      'bookname': '프로젝트 헤일메리 ',
#      'authors': '앤디 위어 지음 ;강동혁 옮김',
#      'publisher': 'RHK(알에이치코리아)',
#      'publication_year': '2021',
#      'isbn13': '9788925588735',
#      'addition_symbol': '04840',
#      'vol': '',
#      'class_no': '843.6',
#      'class_nm': '문학 > 영미문학 > 소설',
#      'loan_count': '238',
#      'bookImageURL': 'https://image.aladin.co.kr/product/27045/43/cover/8925588730_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=5969086'}},
#    {'doc': {'no': 30,
#      'ranking': '30',
#      'bookname': '이처럼 사소한 것들 :클레어 키건 소설 ',
#      'authors': '지은이: 클레어 키건 ;옮긴이: 홍한별',
#      'publisher': '다산북스',
#      'publication_year': '2023',
#      'isbn13': '9791130646381',
#      'addition_symbol': '03840',
#      'vol': '',
#      'class_no': '843.6',
#      'class_nm': '문학 > 영미문학 > 소설',
#      'loan_count': '231',
#      'bookImageURL': 'https://shopping-phinf.pstatic.net/main_4390280/43902803626.20231108182642.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=6791651'}},
#    {'doc': {'no': 31,
#      'ranking': '30',
#      'bookname': '나는 왜 남들보다 쉽게 지칠까 :무던해 보이지만 누구보다 예민한 HSP를 위한 심리학 ',
#      'authors': '최재훈 지음',
#      'publisher': '서스테인',
#      'publication_year': '2024',
#      'isbn13': '9791193388075',
#      'addition_symbol': '03180',
#      'vol': '',
#      'class_no': '182.12',
#      'class_nm': '철학 > 심리학 > 차이심리학',
#      'loan_count': '231',
#      'bookImageURL': 'https://image.aladin.co.kr/product/34214/60/cover200/k482931035_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=6896698'}},
#    {'doc': {'no': 32,
#      'ranking': '32',
#      'bookname': '흰 :한강 소설 ',
#      'authors': '지은이: 한강',
#      'publisher': '문학동네',
#      'publication_year': '2018',
#      'isbn13': '9788954651134',
#      'addition_symbol': '03810',
#      'vol': '',
#      'class_no': '813.62',
#      'class_nm': '문학 > 한국문학 > 소설',
#      'loan_count': '230',
#      'bookImageURL': 'http://image.aladin.co.kr/product/14322/3/cover/8954651135_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=3746119'}},
#    {'doc': {'no': 33,
#      'ranking': '32',
#      'bookname': '(EBS 다큐프라임) 자본주의 ',
#      'authors': 'EBS MEDIA 기획 ;EBS <자본주의> 제작팀 지음',
#      'publisher': '가나문화콘텐츠',
#      'publication_year': '2013',
#      'isbn13': '9788957365793',
#      'addition_symbol': '03320',
#      'vol': '',
#      'class_no': '322.01',
#      'class_nm': '사회과학 > 경제학 > 경제정책',
#      'loan_count': '230',
#      'bookImageURL': 'https://bookthumb-phinf.pstatic.net/cover/073/148/07314866.jpg?type=m1&udate=20170801',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=1975179'}},
#    {'doc': {'no': 34,
#      'ranking': '34',
#      'bookname': '(The) money book :잘 살아갈 우리를 위한 금융생활 안내서 ',
#      'authors': '토스 엮음',
#      'publisher': '비바리퍼블리카',
#      'publication_year': '2024',
#      'isbn13': '9791198686114',
#      'addition_symbol': '03320',
#      'vol': '',
#      'class_no': '327.04',
#      'class_nm': '사회과학 > 경제학 > 금융',
#      'loan_count': '226',
#      'bookImageURL': 'https://image.aladin.co.kr/product/34009/78/cover200/k772931867_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=6880703'}},
#    {'doc': {'no': 35,
#      'ranking': '35',
#      'bookname': '완전한 행복 :정유정 장편소설 ',
#      'authors': '지은이: 정유정',
#      'publisher': '은행나무',
#      'publication_year': '2021',
#      'isbn13': '9791167370280',
#      'addition_symbol': '03810',
#      'vol': '',
#      'class_no': '813.7',
#      'class_nm': '문학 > 한국문학 > 소설',
#      'loan_count': '225',
#      'bookImageURL': 'https://image.aladin.co.kr/product/27225/29/cover/k432732398_2.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=5987427'}},
#    {'doc': {'no': 36,
#      'ranking': '36',
#      'bookname': '파과 :구병모 장편소설 ',
#      'authors': '지은이: 구병모',
#      'publisher': '위즈덤하우스 미디어그룹',
#      'publication_year': '2018',
#      'isbn13': '9791162203620',
#      'addition_symbol': '03810',
#      'vol': '',
#      'class_no': '813.7',
#      'class_nm': '문학 > 한국문학 > 소설',
#      'loan_count': '223',
#      'bookImageURL': 'http://image.aladin.co.kr/product/14224/40/cover/k872532537_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=3742540'}},
#    {'doc': {'no': 37,
#      'ranking': '37',
#      'bookname': '단 한 사람 :최진영 장편소설 ',
#      'authors': '지은이: 최진영',
#      'publisher': '한겨레엔',
#      'publication_year': '2023',
#      'isbn13': '9791160405750',
#      'addition_symbol': '03810',
#      'vol': '',
#      'class_no': '813.7',
#      'class_nm': '문학 > 한국문학 > 소설',
#      'loan_count': '214',
#      'bookImageURL': 'https://image.aladin.co.kr/product/32496/81/cover/k382935719_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=6764215'}},
#    {'doc': {'no': 38,
#      'ranking': '38',
#      'bookname': '트로피컬 나이트 =조예은 소설집 /Tropical night ',
#      'authors': '지은이: 조예은',
#      'publisher': '한겨레엔',
#      'publication_year': '2022',
#      'isbn13': '9791160408331',
#      'addition_symbol': '03810',
#      'vol': '',
#      'class_no': '813.7',
#      'class_nm': '문학 > 한국문학 > 소설',
#      'loan_count': '213',
#      'bookImageURL': 'https://image.aladin.co.kr/product/29946/7/cover/k962838741_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=6541800'}},
#    {'doc': {'no': 39,
#      'ranking': '38',
#      'bookname': '불편한 편의점 :김호연 장편소설',
#      'authors': '지은이: 김호연',
#      'publisher': '나무옆의자',
#      'publication_year': '2022',
#      'isbn13': '9791161571379',
#      'addition_symbol': '03810',
#      'vol': '2',
#      'class_no': '813.7',
#      'class_nm': '문학 > 한국문학 > 소설',
#      'loan_count': '213',
#      'bookImageURL': 'https://image.aladin.co.kr/product/29858/98/cover/k432838027_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=6529613'}},
#    {'doc': {'no': 40,
#      'ranking': '40',
#      'bookname': '돈의 속성 :최상위 부자가 말하는 돈에 대한 모든 것 ',
#      'authors': '지은이: 김승호',
#      'publisher': 'Snowfox(스노우폭스북스)',
#      'publication_year': '2020',
#      'isbn13': '9791188331796',
#      'addition_symbol': '03320',
#      'vol': '',
#      'class_no': '327.04',
#      'class_nm': '사회과학 > 경제학 > 금융',
#      'loan_count': '212',
#      'bookImageURL': 'https://image.aladin.co.kr/product/24191/64/cover/k562639753_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=5678862'}},
#    {'doc': {'no': 41,
#      'ranking': '41',
#      'bookname': '나미야 잡화점의 기적 :히가시노 게이고 장편소설 ',
#      'authors': '지은이: 히가시노 게이고 ;옮긴이: 양윤옥',
#      'publisher': '현대문학',
#      'publication_year': '2012',
#      'isbn13': '9788972756194',
#      'addition_symbol': '03830',
#      'vol': '',
#      'class_no': '833.6',
#      'class_nm': '문학 > 일본문학 > 소설',
#      'loan_count': '209',
#      'bookImageURL': 'http://image.aladin.co.kr/product/15848/6/cover/k622533431_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=1902173'}},
#    {'doc': {'no': 42,
#      'ranking': '42',
#      'bookname': '스노볼 드라이브 :조예은 장편소설 ',
#      'authors': '지은이: 조예은',
#      'publisher': '민음사',
#      'publication_year': '2021',
#      'isbn13': '9788937473319',
#      'addition_symbol': '04810',
#      'vol': '',
#      'class_no': '813.7',
#      'class_nm': '문학 > 한국문학 > 소설',
#      'loan_count': '207',
#      'bookImageURL': 'https://bookthumb-phinf.pstatic.net/cover/180/045/18004516.jpg?type=m1&udate=20210218',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=5882740'}},
#    {'doc': {'no': 43,
#      'ranking': '43',
#      'bookname': '연남동 빙굴빙굴 빨래방 :김지윤 장편소설 ',
#      'authors': '지은이: 김지윤',
#      'publisher': '팩토리나인',
#      'publication_year': '2023',
#      'isbn13': '9791165347734',
#      'addition_symbol': '03810',
#      'vol': '',
#      'class_no': '813.7',
#      'class_nm': '문학 > 한국문학 > 소설',
#      'loan_count': '204',
#      'bookImageURL': 'https://image.aladin.co.kr/product/32131/89/cover/k742834302_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=6738246'}},
#    {'doc': {'no': 44,
#      'ranking': '44',
#      'bookname': '부자 아빠 가난한 아빠 :20주년 특별 기념판 ',
#      'authors': '지은이: 로버트 기요사키 ;옮긴이: 안진환',
#      'publisher': '민음인',
#      'publication_year': '2018',
#      'isbn13': '9791158883591',
#      'addition_symbol': '03320',
#      'vol': '',
#      'class_no': '327.04',
#      'class_nm': '사회과학 > 경제학 > 금융',
#      'loan_count': '202',
#      'bookImageURL': 'http://image.aladin.co.kr/product/13492/56/cover/k162532501_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=3701374'}},
#    {'doc': {'no': 45,
#      'ranking': '44',
#      'bookname': '세이노의 가르침 :피보다 진하게 살아라 ',
#      'authors': '세이노 지음',
#      'publisher': '데이원',
#      'publication_year': '2023',
#      'isbn13': '9791168473690',
#      'addition_symbol': '03190',
#      'vol': '',
#      'class_no': '325.211',
#      'class_nm': '사회과학 > 경제학 > 경영관리',
#      'loan_count': '202',
#      'bookImageURL': 'https://image.aladin.co.kr/product/30929/51/cover/k732831392_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=6628064'}},
#    {'doc': {'no': 46,
#      'ranking': '46',
#      'bookname': '입속 지느러미 :조예은 장편소설 ',
#      'authors': '지은이: 조예은',
#      'publisher': '한겨레엔',
#      'publication_year': '2024',
#      'isbn13': '9791172130633',
#      'addition_symbol': '04810',
#      'vol': '',
#      'class_no': '813.7',
#      'class_nm': '문학 > 한국문학 > 소설',
#      'loan_count': '201',
#      'bookImageURL': 'https://image.aladin.co.kr/product/34002/54/cover200/k462930652_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=6879532'}},
#    {'doc': {'no': 47,
#      'ranking': '47',
#      'bookname': '아이가 없는 집 ',
#      'authors': '지은이: 알렉스 안도릴 ;옮긴이: 유혜인',
#      'publisher': '필름',
#      'publication_year': '2024',
#      'isbn13': '9791193262184',
#      'addition_symbol': '03850',
#      'vol': '',
#      'class_no': '859.7',
#      'class_nm': '문학 > 독일문학 > 기타 게르만 문학',
#      'loan_count': '200',
#      'bookImageURL': 'https://image.aladin.co.kr/product/34117/59/cover200/k962931994_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=6890223'}},
#    {'doc': {'no': 48,
#      'ranking': '48',
#      'bookname': '아주 작은 습관의 힘 :최고의 변화는 어떻게 만들어지는가 ',
#      'authors': '제임스 클리어 지음 ;이한이 옮김',
#      'publisher': '비즈니스북스',
#      'publication_year': '2019',
#      'isbn13': '9791162540640',
#      'addition_symbol': '03190',
#      'vol': '',
#      'class_no': '181.845',
#      'class_nm': '철학 > 심리학 > 각론',
#      'loan_count': '199',
#      'bookImageURL': 'https://image.aladin.co.kr/product/18228/51/cover/k832534441_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=5368180'}},
#    {'doc': {'no': 49,
#      'ranking': '49',
#      'bookname': '귀신들의 땅 :천쓰홍 장편 소설 ',
#      'authors': '지은이: 천쓰홍 ;옮긴이: 김태성',
#      'publisher': '민음사',
#      'publication_year': '2023',
#      'isbn13': '9788937454820',
#      'addition_symbol': '03820',
#      'vol': '',
#      'class_no': '823.7',
#      'class_nm': '문학 > 중국문학 > 소설',
#      'loan_count': '196',
#      'bookImageURL': 'https://image.aladin.co.kr/product/33119/32/cover/8937454823_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=6811808'}},
#    {'doc': {'no': 50,
#      'ranking': '49',
#      'bookname': '달러구트 꿈 백화점 :이미예 장편소설',
#      'authors': '지은이: 이미예',
#      'publisher': '팩토리나인',
#      'publication_year': '2021',
#      'isbn13': '9791165343729',
#      'addition_symbol': '03810',
#      'vol': '2',
#      'class_no': '813.7',
#      'class_nm': '문학 > 한국문학 > 소설',
#      'loan_count': '196',
#      'bookImageURL': 'https://image.aladin.co.kr/product/27587/47/cover/k962733015_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=6049391'}},
#    {'doc': {'no': 51,
#      'ranking': '51',
#      'bookname': '내게 무해한 사람 :최은영 소설 ',
#      'authors': '지은이: 최은영',
#      'publisher': '문학동네',
#      'publication_year': '2018',
#      'isbn13': '9788954651820',
#      'addition_symbol': '03810',
#      'vol': '',
#      'class_no': '813.7',
#      'class_nm': '문학 > 한국문학 > 소설',
#      'loan_count': '193',
#      'bookImageURL': 'https://image.aladin.co.kr/product/15133/51/cover/8954651828_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=3774162'}},
#    {'doc': {'no': 52,
#      'ranking': '51',
#      'bookname': '오렌지와 빵칼 =청예 장편소설 /Orange and bread knife ',
#      'authors': '지은이: 청예',
#      'publisher': '허블',
#      'publication_year': '2024',
#      'isbn13': '9791193078259',
#      'addition_symbol': '03810',
#      'vol': '',
#      'class_no': '813.7',
#      'class_nm': '문학 > 한국문학 > 소설',
#      'loan_count': '193',
#      'bookImageURL': 'https://image.aladin.co.kr/product/34259/77/cover200/k852932962_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=6901042'}},
#    {'doc': {'no': 53,
#      'ranking': '53',
#      'bookname': '이끼숲 :천선란 연작소설 ',
#      'authors': '지은이: 천선란 ;일러스트: 점선면',
#      'publisher': '자이언트북스',
#      'publication_year': '2023',
#      'isbn13': '9791191824216',
#      'addition_symbol': '03810',
#      'vol': '',
#      'class_no': '813.7',
#      'class_nm': '문학 > 한국문학 > 소설',
#      'loan_count': '192',
#      'bookImageURL': 'https://image.aladin.co.kr/product/31568/81/cover/k672832652_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=6682814'}},
#    {'doc': {'no': 54,
#      'ranking': '54',
#      'bookname': '7년의 밤 :정유정 장편소설 ',
#      'authors': '지은이: 정유정',
#      'publisher': '은행나무',
#      'publication_year': '2011',
#      'isbn13': '9788956604992',
#      'addition_symbol': '03810',
#      'vol': '',
#      'class_no': '813.7',
#      'class_nm': '문학 > 한국문학 > 소설',
#      'loan_count': '189',
#      'bookImageURL': 'http://image.aladin.co.kr/product/14712/55/cover/k202532053_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=1153285'}},
#    {'doc': {'no': 55,
#      'ranking': '55',
#      'bookname': '삼체 =The three body ',
#      'authors': '류츠신 지음 ;허유영 옮김',
#      'publisher': '자음과모음',
#      'publication_year': '2020',
#      'isbn13': '9788954442695',
#      'addition_symbol': '04820',
#      'vol': '1',
#      'class_no': '823.7',
#      'class_nm': '문학 > 중국문학 > 소설',
#      'loan_count': '188',
#      'bookImageURL': 'https://image.aladin.co.kr/product/28912/65/cover/8954442692_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=5708402'}},
#    {'doc': {'no': 56,
#      'ranking': '55',
#      'bookname': '그의 운명에 대한 아주 개인적인 생각 ',
#      'authors': '지은이: 유시민',
#      'publisher': '아름다운사람들',
#      'publication_year': '2024',
#      'isbn13': '9788965138068',
#      'addition_symbol': '03300',
#      'vol': '',
#      'class_no': '340.911',
#      'class_nm': '사회과학 > 정치학 > 정치학',
#      'loan_count': '188',
#      'bookImageURL': 'https://image.aladin.co.kr/product/34121/16/cover200/s812931190_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=6890222'}},
#    {'doc': {'no': 57,
#      'ranking': '57',
#      'bookname': '아몬드손원평 장편소설',
#      'authors': '손원평',
#      'publisher': '창비',
#      'publication_year': '2017',
#      'isbn13': '9788936434267',
#      'addition_symbol': '03810',
#      'vol': '',
#      'class_no': '813.7',
#      'class_nm': '문학 > 한국문학 > 소설',
#      'loan_count': '187',
#      'bookImageURL': 'http://image.aladin.co.kr/product/16839/4/cover/k492534773_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=3423096'}},
#    {'doc': {'no': 58,
#      'ranking': '57',
#      'bookname': '아버지의 해방일지 :정지아 장편소설 ',
#      'authors': '지은이: 정지아',
#      'publisher': '창비',
#      'publication_year': '2022',
#      'isbn13': '9788936438838',
#      'addition_symbol': '03810',
#      'vol': '',
#      'class_no': '813.62',
#      'class_nm': '문학 > 한국문학 > 소설',
#      'loan_count': '187',
#      'bookImageURL': 'https://image.aladin.co.kr/product/30048/51/cover/8936438832_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=6551957'}},
#    {'doc': {'no': 59,
#      'ranking': '59',
#      'bookname': '더 좋은 삶을 위한 철학 ',
#      'authors': '지은이: 마이클 슈어 ;옮긴이: 염지선',
#      'publisher': '김영사',
#      'publication_year': '2023',
#      'isbn13': '9788934965909',
#      'addition_symbol': '03190',
#      'vol': '',
#      'class_no': '190',
#      'class_nm': '철학 > 윤리학, 도덕철학 > 윤리학, 도덕철학',
#      'loan_count': '186',
#      'bookImageURL': 'https://image.aladin.co.kr/product/31132/45/cover/8934965908_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=6643878'}},
#    {'doc': {'no': 60,
#      'ranking': '59',
#      'bookname': '미드나잇 라이브러리 ',
#      'authors': '매트 헤이그 지음 ;노진선 옮김',
#      'publisher': '인플루엔셜',
#      'publication_year': '2021',
#      'isbn13': '9791191056556',
#      'addition_symbol': '03840',
#      'vol': '',
#      'class_no': '843.6',
#      'class_nm': '문학 > 영미문학 > 소설',
#      'loan_count': '186',
#      'bookImageURL': 'https://image.aladin.co.kr/product/26987/37/cover/k962730610_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=5965665'}},
#    {'doc': {'no': 61,
#      'ranking': '59',
#      'bookname': '탕비실 :이미예 소설 ',
#      'authors': '지은이: 이미예',
#      'publisher': '오팬하우스',
#      'publication_year': '2024',
#      'isbn13': '9791198809940',
#      'addition_symbol': '03810',
#      'vol': '',
#      'class_no': '813.7',
#      'class_nm': '문학 > 한국문학 > 소설',
#      'loan_count': '186',
#      'bookImageURL': 'https://image.aladin.co.kr/product/34193/41/cover200/k602931315_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=6894621'}},
#    {'doc': {'no': 62,
#      'ranking': '62',
#      'bookname': '흰 :한강 소설 ',
#      'authors': '지은이: 한강',
#      'publisher': '문학동네',
#      'publication_year': '2016',
#      'isbn13': '9788954640718',
#      'addition_symbol': '03810',
#      'vol': '',
#      'class_no': '813.62',
#      'class_nm': '문학 > 한국문학 > 소설',
#      'loan_count': '181',
#      'bookImageURL': 'http://image.aladin.co.kr/product/8466/1/cover/k712535369_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=3153205'}},
#    {'doc': {'no': 63,
#      'ranking': '62',
#      'bookname': '파견자들 :김초엽 장편소설 ',
#      'authors': '지은이: 김초엽',
#      'publisher': '퍼블리온',
#      'publication_year': '2023',
#      'isbn13': '9791191587524',
#      'addition_symbol': '03810',
#      'vol': '',
#      'class_no': '813.7',
#      'class_nm': '문학 > 한국문학 > 소설',
#      'loan_count': '181',
#      'bookImageURL': 'https://image.aladin.co.kr/product/32591/29/cover/k352935549_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=6772199'}},
#    {'doc': {'no': 64,
#      'ranking': '64',
#      'bookname': '서랍에 저녁을 넣어 두었다 :한강 시집 ',
#      'authors': '지은이: 한강',
#      'publisher': '문학과지성사',
#      'publication_year': '2013',
#      'isbn13': '9788932024639',
#      'addition_symbol': '03810',
#      'vol': '',
#      'class_no': '811.62',
#      'class_nm': '문학 > 한국문학 > 시',
#      'loan_count': '180',
#      'bookImageURL': 'http://image.aladin.co.kr/product/3335/59/cover/8932024634_3.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=1991954'}},
#    {'doc': {'no': 65,
#      'ranking': '65',
#      'bookname': '저주토끼 (리커버)',
#      'authors': '정보라 (지은이)',
#      'publisher': '아작',
#      'publication_year': '2022',
#      'isbn13': '9791166686665',
#      'addition_symbol': '',
#      'vol': '',
#      'class_no': '',
#      'class_nm': ' >  > ',
#      'loan_count': '178',
#      'bookImageURL': 'https://image.aladin.co.kr/product/29084/68/cover/k122836656_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=6424905'}},
#    {'doc': {'no': 66,
#      'ranking': '66',
#      'bookname': '왜 나는 너를 사랑하는가',
#      'authors': '알랭 드 보통 [지음];정영목 옮김',
#      'publisher': '청미래',
#      'publication_year': '2007',
#      'isbn13': '9788986836240',
#      'addition_symbol': '03840',
#      'vol': '',
#      'class_no': '843',
#      'class_nm': '문학 > 영미문학 > 소설',
#      'loan_count': '177',
#      'bookImageURL': 'https://bookthumb-phinf.pstatic.net/cover/030/257/03025716.jpg?type=m1&udate=20180227',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=2130072'}},
#    {'doc': {'no': 67,
#      'ranking': '67',
#      'bookname': '해가 지는 곳으로 :최진영 장편소설 ',
#      'authors': '지은이: 최진영',
#      'publisher': '민음사',
#      'publication_year': '2017',
#      'isbn13': '9788937473166',
#      'addition_symbol': '04810',
#      'vol': '',
#      'class_no': '813.7',
#      'class_nm': '문학 > 한국문학 > 소설',
#      'loan_count': '175',
#      'bookImageURL': 'http://image.aladin.co.kr/product/11281/18/cover/893747316x_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=3468676'}},
#    {'doc': {'no': 68,
#      'ranking': '67',
#      'bookname': '이중 하나는 거짓말 :김애란 장편소설 ',
#      'authors': '지은이: 김애란',
#      'publisher': '문학동네',
#      'publication_year': '2024',
#      'isbn13': '9791141601300',
#      'addition_symbol': '03810',
#      'vol': '',
#      'class_no': '813.7',
#      'class_nm': '문학 > 한국문학 > 소설',
#      'loan_count': '175',
#      'bookImageURL': 'https://image.aladin.co.kr/product/34474/76/cover200/k292932634_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=6933234'}},
#    {'doc': {'no': 69,
#      'ranking': '67',
#      'bookname': '돈의 심리학 :당신은 왜 부자가 되지 못했는가 ',
#      'authors': '모건 하우절 지음 ;이지연 옮김',
#      'publisher': '인플루엔셜',
#      'publication_year': '2021',
#      'isbn13': '9791191056372',
#      'addition_symbol': '03320',
#      'vol': '',
#      'class_no': '327.04',
#      'class_nm': '사회과학 > 경제학 > 금융',
#      'loan_count': '175',
#      'bookImageURL': 'https://image.aladin.co.kr/product/25967/85/cover/k412737326_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=5846583'}},
#    {'doc': {'no': 70,
#      'ranking': '70',
#      'bookname': '다정한 것이 살아남는다 ',
#      'authors': '지은이: 브라이언 헤어,옮긴이: 이민아',
#      'publisher': '디플롯',
#      'publication_year': '2021',
#      'isbn13': '9791197413025',
#      'addition_symbol': '03400',
#      'vol': '',
#      'class_no': '182.4',
#      'class_nm': '철학 > 심리학 > 차이심리학',
#      'loan_count': '174',
#      'bookImageURL': 'https://image.aladin.co.kr/product/27608/83/cover/k722733028_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=6060921'}},
#    {'doc': {'no': 71,
#      'ranking': '71',
#      'bookname': '크리스마스 타일 :김금희 연작소설 ',
#      'authors': '지은이: 김금희',
#      'publisher': '창비',
#      'publication_year': '2022',
#      'isbn13': '9788936438890',
#      'addition_symbol': '03810',
#      'vol': '',
#      'class_no': '813.7',
#      'class_nm': '문학 > 한국문학 > 소설',
#      'loan_count': '173',
#      'bookImageURL': 'https://image.aladin.co.kr/product/30520/41/cover/8936438891_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=6595121'}},
#    {'doc': {'no': 72,
#      'ranking': '71',
#      'bookname': '적산가옥의 유령 :조예은 소설 ',
#      'authors': '지은이: 조예은',
#      'publisher': 'H(현대문학)',
#      'publication_year': '2024',
#      'isbn13': '9791167902580',
#      'addition_symbol': '04810',
#      'vol': '',
#      'class_no': '813.7',
#      'class_nm': '문학 > 한국문학 > 소설',
#      'loan_count': '173',
#      'bookImageURL': 'https://image.aladin.co.kr/product/34286/38/cover200/k592932077_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=6905353'}},
#    {'doc': {'no': 73,
#      'ranking': '73',
#      'bookname': '쇼코의 미소 :최은영 소설 ',
#      'authors': '지은이: 최은영',
#      'publisher': '문학동네',
#      'publication_year': '2016',
#      'isbn13': '9788954641630',
#      'addition_symbol': '03810',
#      'vol': '',
#      'class_no': '813.7',
#      'class_nm': '문학 > 한국문학 > 소설',
#      'loan_count': '172',
#      'bookImageURL': 'https://bookthumb-phinf.pstatic.net/cover/107/859/10785953.jpg?type=m1&udate=20180717',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=3190615'}},
#    {'doc': {'no': 74,
#      'ranking': '73',
#      'bookname': '타이탄의 도구들 :1만 시간의 법칙을 깬 거인들의 61가지 전략 ',
#      'authors': '팀 페리스 지음 ;정지현 옮김',
#      'publisher': 'Tornado(토네이도)',
#      'publication_year': '2017',
#      'isbn13': '9791158510619',
#      'addition_symbol': '03190',
#      'vol': '',
#      'class_no': '325.211',
#      'class_nm': '사회과학 > 경제학 > 경영관리',
#      'loan_count': '172',
#      'bookImageURL': 'http://image.aladin.co.kr/product/10590/57/cover/k162530537_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=3423727'}},
#    {'doc': {'no': 75,
#      'ranking': '75',
#      'bookname': '피프티 피플 :정세랑 장편소설 ',
#      'authors': '지은이: 정세랑',
#      'publisher': '창비',
#      'publication_year': '2016',
#      'isbn13': '9788936434243',
#      'addition_symbol': '03810',
#      'vol': '',
#      'class_no': '813.7',
#      'class_nm': '문학 > 한국문학 > 소설',
#      'loan_count': '169',
#      'bookImageURL': 'https://bookthumb-phinf.pstatic.net/cover/113/062/11306271.jpg?type=m1&udate=20180117',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=3391014'}},
#    {'doc': {'no': 76,
#      'ranking': '76',
#      'bookname': '내가 틀릴 수도 있습니다 =숲속의 현자가 전하는 마지막 인생수업 /I may be wrong ',
#      'authors': '비욘 나티코 린데블라드 지음 ;박미경 옮김',
#      'publisher': '다산북스',
#      'publication_year': '2022',
#      'isbn13': '9791130689890',
#      'addition_symbol': '03100',
#      'vol': '',
#      'class_no': '220.4',
#      'class_nm': '종교 > 불교 > 불교',
#      'loan_count': '168',
#      'bookImageURL': 'https://image.aladin.co.kr/product/29269/12/cover/k822837807_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=6445483'}},
#    {'doc': {'no': 77,
#      'ranking': '77',
#      'bookname': '메리골드 마음 세탁소 =윤정은 장편소설 /Marigold mind laundry ',
#      'authors': '글: 윤정은',
#      'publisher': '북로망스',
#      'publication_year': '2023',
#      'isbn13': '9791191891287',
#      'addition_symbol': '03810',
#      'vol': '',
#      'class_no': '813.7',
#      'class_nm': '문학 > 한국문학 > 소설',
#      'loan_count': '167',
#      'bookImageURL': 'https://image.aladin.co.kr/product/31222/5/cover/k562831250_2.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=6648006'}},
#    {'doc': {'no': 78,
#      'ranking': '78',
#      'bookname': '눈부신 안부 :백수린 장편소설 ',
#      'authors': '지은이: 백수린',
#      'publisher': '문학동네',
#      'publication_year': '2023',
#      'isbn13': '9788954699372',
#      'addition_symbol': '03810',
#      'vol': '',
#      'class_no': '813.7',
#      'class_nm': '문학 > 한국문학 > 소설',
#      'loan_count': '166',
#      'bookImageURL': 'https://image.aladin.co.kr/product/31688/62/cover/8954699375_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=6694629'}},
#    {'doc': {'no': 79,
#      'ranking': '79',
#      'bookname': '랑과 나의 사막 :천선란 소설 ',
#      'authors': '지은이: 천선란',
#      'publisher': 'H(현대문학)',
#      'publication_year': '2022',
#      'isbn13': '9791167901354',
#      'addition_symbol': '04810',
#      'vol': '',
#      'class_no': '813.7',
#      'class_nm': '문학 > 한국문학 > 소설',
#      'loan_count': '165',
#      'bookImageURL': 'https://image.aladin.co.kr/product/30395/18/cover/k572830160_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=6580839'}},
#    {'doc': {'no': 80,
#      'ranking': '80',
#      'bookname': '두 사람의 인터내셔널 :김기태 소설 ',
#      'authors': '지은이: 김기태',
#      'publisher': '문학동네',
#      'publication_year': '2024',
#      'isbn13': '9788954697941',
#      'addition_symbol': '03810',
#      'vol': '',
#      'class_no': '813.7',
#      'class_nm': '문학 > 한국문학 > 소설',
#      'loan_count': '163',
#      'bookImageURL': 'https://image.aladin.co.kr/product/33899/7/cover200/8954697941_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=6873522'}},
#    {'doc': {'no': 81,
#      'ranking': '81',
#      'bookname': '가면산장 살인사건 ',
#      'authors': '지은이: 히가시노 게이고 ;옮긴이: 김난주',
#      'publisher': '재인',
#      'publication_year': '2014',
#      'isbn13': '9788990982575',
#      'addition_symbol': '03830',
#      'vol': '',
#      'class_no': '833.6',
#      'class_nm': '문학 > 일본문학 > 소설',
#      'loan_count': '158',
#      'bookImageURL': 'http://image.aladin.co.kr/product/4745/51/cover/899098257x_2.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=2427470'}},
#    {'doc': {'no': 82,
#      'ranking': '82',
#      'bookname': '방금 떠나온 세계 :김초엽 소설집 ',
#      'authors': '지은이: 김초엽',
#      'publisher': '한겨레엔',
#      'publication_year': '2021',
#      'isbn13': '9791160406504',
#      'addition_symbol': '03810',
#      'vol': '',
#      'class_no': '813.7',
#      'class_nm': '문학 > 한국문학 > 소설',
#      'loan_count': '156',
#      'bookImageURL': 'https://image.aladin.co.kr/product/28170/22/cover/k032835560_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=6322276'}},
#    {'doc': {'no': 83,
#      'ranking': '82',
#      'bookname': '시대예보 :핵개인의 시대 =Forecast of the times : era of nuclear individuals ',
#      'authors': '저자: 송길영',
#      'publisher': '교보문고',
#      'publication_year': '2023',
#      'isbn13': '9791170610359',
#      'addition_symbol': '03320',
#      'vol': '',
#      'class_no': '331.544',
#      'class_nm': '사회과학 > 사회학, 사회문제 > 사회학',
#      'loan_count': '156',
#      'bookImageURL': 'https://image.aladin.co.kr/product/32462/56/cover/k942935205_3.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=6761221'}},
#    {'doc': {'no': 84,
#      'ranking': '84',
#      'bookname': '용의자 X의 헌신 ',
#      'authors': '히가시노 게이고 지음 ;양억관 옮김',
#      'publisher': '재인',
#      'publication_year': '2017',
#      'isbn13': '9788990982704',
#      'addition_symbol': '03830',
#      'vol': '',
#      'class_no': '833.6',
#      'class_nm': '문학 > 일본문학 > 소설',
#      'loan_count': '155',
#      'bookImageURL': 'https://bookthumb-phinf.pstatic.net/cover/124/818/12481857.jpg?type=m1&udate=20170914',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=3541024'}},
#    {'doc': {'no': 85,
#      'ranking': '85',
#      'bookname': '도파민네이션 :쾌락 과잉 시대에서 균형 찾기 ',
#      'authors': '애나 렘키 지음 ;김두완 옮김',
#      'publisher': '흐름출판',
#      'publication_year': '2022',
#      'isbn13': '9788965965046',
#      'addition_symbol': '03180',
#      'vol': '',
#      'class_no': '181.71',
#      'class_nm': '철학 > 심리학 > 각론',
#      'loan_count': '154',
#      'bookImageURL': 'https://image.aladin.co.kr/product/29125/5/cover/8965965047_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=6428072'}},
#    {'doc': {'no': 86,
#      'ranking': '85',
#      'bookname': '악마의 계약서는 만기 되지 않는다 :리러하 장편소설 ',
#      'authors': '지은이: 리러하',
#      'publisher': '팩토리나인',
#      'publication_year': '2022',
#      'isbn13': '9791165345839',
#      'addition_symbol': '03810',
#      'vol': '',
#      'class_no': '813.7',
#      'class_nm': '문학 > 한국문학 > 소설',
#      'loan_count': '154',
#      'bookImageURL': 'https://image.aladin.co.kr/product/29885/33/cover/k712838837_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=6535280'}},
#    {'doc': {'no': 87,
#      'ranking': '87',
#      'bookname': '영원한 천국 :정유정 장편소설 ',
#      'authors': '지은이: 정유정',
#      'publisher': '은행나무',
#      'publication_year': '2024',
#      'isbn13': '9791167374561',
#      'addition_symbol': '03810',
#      'vol': '',
#      'class_no': '813.7',
#      'class_nm': '문학 > 한국문학 > 소설',
#      'loan_count': '153',
#      'bookImageURL': 'https://image.aladin.co.kr/product/34499/81/cover200/k712932751_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=6934298'}},
#    {'doc': {'no': 88,
#      'ranking': '88',
#      'bookname': '브람스를 좋아하세요 ',
#      'authors': '프랑수아즈 사강 [지음] ;김남주 옮김',
#      'publisher': '민음사',
#      'publication_year': '2008',
#      'isbn13': '9788937461798',
#      'addition_symbol': '04800',
#      'vol': '179',
#      'class_no': '863',
#      'class_nm': '문학 > 프랑스문학 > 소설',
#      'loan_count': '151',
#      'bookImageURL': 'https://bookthumb-phinf.pstatic.net/cover/045/694/04569434.jpg?type=m1&udate=20130412',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=2374505'}},
#    {'doc': {'no': 89,
#      'ranking': '88',
#      'bookname': '사랑과 결함 :예소연 소설 ',
#      'authors': '지은이: 예소연',
#      'publisher': '문학동네',
#      'publication_year': '2024',
#      'isbn13': '9791141601102',
#      'addition_symbol': '03810',
#      'vol': '',
#      'class_no': '813.7',
#      'class_nm': '문학 > 한국문학 > 소설',
#      'loan_count': '151',
#      'bookImageURL': 'https://image.aladin.co.kr/product/34366/96/cover200/k972932005_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=6922272'}},
#    {'doc': {'no': 90,
#      'ranking': '90',
#      'bookname': '국가란 무엇인가 ',
#      'authors': '유시민 지음',
#      'publisher': '돌베개',
#      'publication_year': '2017',
#      'isbn13': '9788971998014',
#      'addition_symbol': '03340',
#      'vol': '',
#      'class_no': '341',
#      'class_nm': '사회과학 > 정치학 > 국가형태',
#      'loan_count': '150',
#      'bookImageURL': 'http://image.aladin.co.kr/product/10115/84/cover/8971998016_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=3408932'}},
#    {'doc': {'no': 91,
#      'ranking': '90',
#      'bookname': '어서오세요, 휴남동 서점입니다 :황보름 장편소설 ',
#      'authors': '지은이: 황보름',
#      'publisher': '클레이하우스',
#      'publication_year': '2022',
#      'isbn13': '9791197377143',
#      'addition_symbol': '03810',
#      'vol': '',
#      'class_no': '813.7',
#      'class_nm': '문학 > 한국문학 > 소설',
#      'loan_count': '150',
#      'bookImageURL': 'https://image.aladin.co.kr/product/28685/95/cover/k362836265_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=6389692'}},
#    {'doc': {'no': 92,
#      'ranking': '92',
#      'bookname': '눈에 갇힌 외딴 산장에서',
#      'authors': '히가시노 게이고 (지은이), 김난주 (옮긴이)',
#      'publisher': '재인',
#      'publication_year': '2023',
#      'isbn13': '9791192483191',
#      'addition_symbol': '',
#      'vol': '',
#      'class_no': '',
#      'class_nm': ' >  > ',
#      'loan_count': '148',
#      'bookImageURL': 'https://image.aladin.co.kr/product/32089/67/cover/k522834190_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=6734083'}},
#    {'doc': {'no': 93,
#      'ranking': '93',
#      'bookname': '나는 메트로폴리탄 미술관의 경비원입니다 :가장 경이로운 세계 속으로 숨어버린 한 남자의 이야기 ',
#      'authors': '패트릭 브링리 지음 ;조현주 옮김',
#      'publisher': '웅진씽크빅',
#      'publication_year': '2023',
#      'isbn13': '9788901276533',
#      'addition_symbol': '03840',
#      'vol': '',
#      'class_no': '848',
#      'class_nm': '문학 > 영미문학 > 르포르타주 및 기타',
#      'loan_count': '147',
#      'bookImageURL': 'https://image.aladin.co.kr/product/32892/38/cover/8901276534_2.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=6793850'}},
#    {'doc': {'no': 94,
#      'ranking': '93',
#      'bookname': '예루살렘의 아이히만',
#      'authors': '한나 아렌트 지음;김선욱 옮김',
#      'publisher': '한길사',
#      'publication_year': '2006',
#      'isbn13': '9788935656615',
#      'addition_symbol': '94160',
#      'vol': '',
#      'class_no': '909.54',
#      'class_nm': '역사 > 역사 > 세계사, 세계문화사',
#      'loan_count': '147',
#      'bookImageURL': 'https://bookthumb-phinf.pstatic.net/cover/025/276/02527697.jpg?type=m1&udate=20161020',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=2062893'}},
#    {'doc': {'no': 95,
#      'ranking': '93',
#      'bookname': '당신은 결국 무엇이든 해내는 사람 :김상현 에세이 ',
#      'authors': '지은이: 김상현',
#      'publisher': '필름(필름출판사)',
#      'publication_year': '2022',
#      'isbn13': '9791188469994',
#      'addition_symbol': '03810',
#      'vol': '',
#      'class_no': '818',
#      'class_nm': '문학 > 한국문학 > 르포르타주 및 기타',
#      'loan_count': '147',
# ...
#      'class_nm': '철학 > 심리학 > 차이심리학',
#      'loan_count': '109',
#      'bookImageURL': 'http://image.aladin.co.kr/product/8679/31/cover/k372535696_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=3320490'}},
#    {'doc': {'no': 170,
#      'ranking': '167',
#      'bookname': '딸아, 돈 공부 절대 미루지 마라 :돈과 인생에 대한 가장 현실적인 조언 50 ',
#      'authors': '박소연 지음',
#      'publisher': '메이븐',
#      'publication_year': '2023',
#      'isbn13': '9791190538572',
#      'addition_symbol': '03190',
#      'vol': '',
#      'class_no': '327.04',
#      'class_nm': '사회과학 > 경제학 > 금융',
#      'loan_count': '109',
#      'bookImageURL': 'https://image.aladin.co.kr/product/31657/95/cover/k092833678_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=6693602'}},
#    {'doc': {'no': 171,
#      'ranking': '171',
#      'bookname': '비행운 :김애란 소설집 ',
#      'authors': '지은이: 김애란',
#      'publisher': '문학과지성사',
#      'publication_year': '2012',
#      'isbn13': '9788932023151',
#      'addition_symbol': '03810',
#      'vol': '',
#      'class_no': '813.7',
#      'class_nm': '문학 > 한국문학 > 소설',
#      'loan_count': '108',
#      'bookImageURL': 'http://image.aladin.co.kr/product/1801/21/cover/8932023158_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=1855307'}},
#    {'doc': {'no': 172,
#      'ranking': '171',
#      'bookname': '마법소녀 은퇴합니다 :박서련 소설 ',
#      'authors': '지은이: 박서련',
#      'publisher': '창비',
#      'publication_year': '2022',
#      'isbn13': '9788936438739',
#      'addition_symbol': '03810',
#      'vol': '',
#      'class_no': '813.7',
#      'class_nm': '문학 > 한국문학 > 소설',
#      'loan_count': '108',
#      'bookImageURL': 'https://image.aladin.co.kr/product/29250/64/cover/8936438735_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=6442398'}},
#    {'doc': {'no': 173,
#      'ranking': '171',
#      'bookname': '정의란 무엇인가 ',
#      'authors': '지은이: 마이클 샌델 ;옮긴이: 김명철',
#      'publisher': '미래엔',
#      'publication_year': '2014',
#      'isbn13': '9788937834790',
#      'addition_symbol': '03300',
#      'vol': '',
#      'class_no': '193',
#      'class_nm': '철학 > 윤리학, 도덕철학 > 국가 및 정치윤리',
#      'loan_count': '108',
#      'bookImageURL': 'http://image.aladin.co.kr/product/10826/23/cover/k742530554_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=2763903'}},
#    {'doc': {'no': 174,
#      'ranking': '171',
#      'bookname': '거인의 노트 :인생에서 무엇을 보고 어떻게 기록할 것인가 ',
#      'authors': '김익한 지음',
#      'publisher': '다산북스',
#      'publication_year': '2023',
#      'isbn13': '9791130697529',
#      'addition_symbol': '03190',
#      'vol': '',
#      'class_no': '325.211',
#      'class_nm': '사회과학 > 경제학 > 경영관리',
#      'loan_count': '108',
#      'bookImageURL': 'https://shopping-phinf.pstatic.net/main_3830325/38303250624.20230302071138.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=6650346'}},
#    {'doc': {'no': 175,
#      'ranking': '175',
#      'bookname': '이기적 유전자 ',
#      'authors': '리처드 도킨스 지음 ;이상임 옮김',
#      'publisher': '을유문화사',
#      'publication_year': '2018',
#      'isbn13': '9788932473901',
#      'addition_symbol': '03470',
#      'vol': '',
#      'class_no': '491.51',
#      'class_nm': '자연과학 > 동물학 > 일반 동물학',
#      'loan_count': '107',
#      'bookImageURL': 'https://image.aladin.co.kr/product/17048/25/cover/8932473900_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=3921678'}},
#    {'doc': {'no': 176,
#      'ranking': '175',
#      'bookname': '불안 ',
#      'authors': '지은이: 알랭 드 보통 ;정영목 옮김',
#      'publisher': '은행나무',
#      'publication_year': '2012',
#      'isbn13': '9788956605593',
#      'addition_symbol': '03840',
#      'vol': '',
#      'class_no': '332.6',
#      'class_nm': '사회과학 > 사회학, 사회문제 > 사회조직 및 제도',
#      'loan_count': '107',
#      'bookImageURL': 'https://bookthumb-phinf.pstatic.net/cover/067/930/06793081.jpg?type=m1&udate=20171011',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=1226611'}},
#    {'doc': {'no': 177,
#      'ranking': '175',
#      'bookname': '한 스푼의 시간 :구병모 장편소설 ',
#      'authors': '지은이: 구병모',
#      'publisher': '위즈덤하우스',
#      'publication_year': '2016',
#      'isbn13': '9788959130580',
#      'addition_symbol': '03810',
#      'vol': '',
#      'class_no': '813.7',
#      'class_nm': '문학 > 한국문학 > 소설',
#      'loan_count': '107',
#      'bookImageURL': 'http://image.aladin.co.kr/product/9131/24/cover/8959130583_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=3326576'}},
#    {'doc': {'no': 178,
#      'ranking': '175',
#      'bookname': '만조를 기다리며 :우리 숨바꼭질 기억해? ',
#      'authors': '지은이: 조예은',
#      'publisher': '위즈덤하우스',
#      'publication_year': '2023',
#      'isbn13': '9791168127128',
#      'addition_symbol': '04810',
#      'vol': '',
#      'class_no': '813.7',
#      'class_nm': '문학 > 한국문학 > 소설',
#      'loan_count': '107',
#      'bookImageURL': 'https://image.aladin.co.kr/product/31681/11/cover/k062833889_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=6693802'}},
#    {'doc': {'no': 179,
#      'ranking': '179',
#      'bookname': '언러키 스타트업 :정지음 시트콤소설 ',
#      'authors': '지은이: 정지음',
#      'publisher': '민음사',
#      'publication_year': '2022',
#      'isbn13': '9788937427343',
#      'addition_symbol': '03810',
#      'vol': '',
#      'class_no': '813.7',
#      'class_nm': '문학 > 한국문학 > 소설',
#      'loan_count': '106',
#      'bookImageURL': 'https://image.aladin.co.kr/product/30275/85/cover/8937427346_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=6572502'}},
#    {'doc': {'no': 180,
#      'ranking': '179',
#      'bookname': '나의 한국현대사 :1959-2020 ',
#      'authors': '유시민 지음',
#      'publisher': '돌베개',
#      'publication_year': '2021',
#      'isbn13': '9788971999080',
#      'addition_symbol': '03910',
#      'vol': '',
#      'class_no': '911.07',
#      'class_nm': '역사 > 아시아(아세아) > 한국',
#      'loan_count': '106',
#      'bookImageURL': 'https://image.aladin.co.kr/product/26075/76/cover/897199908x_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=5849773'}},
#    {'doc': {'no': 181,
#      'ranking': '179',
#      'bookname': '희망 :양귀자 장편소설 ',
#      'authors': '지은이: 양귀자',
#      'publisher': '쓰다',
#      'publication_year': '2020',
#      'isbn13': '9788998441081',
#      'addition_symbol': '03810',
#      'vol': '',
#      'class_no': '813.62',
#      'class_nm': '문학 > 한국문학 > 소설',
#      'loan_count': '106',
#      'bookImageURL': 'https://image.aladin.co.kr/product/24415/15/cover/899844108x_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=5701868'}},
#    {'doc': {'no': 182,
#      'ranking': '179',
#      'bookname': '바다가 들리는 편의점 ',
#      'authors': '마치다 소노코 지음 ;황국영 옮김',
#      'publisher': '바이포엠 스튜디오',
#      'publication_year': '2023',
#      'isbn13': '9791192579504',
#      'addition_symbol': '03830',
#      'vol': '',
#      'class_no': '833.6',
#      'class_nm': '문학 > 일본문학 > 소설',
#      'loan_count': '106',
#      'bookImageURL': 'https://shopping-phinf.pstatic.net/main_3878746/38787460621.20230320201202.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=6661646'}},
#    {'doc': {'no': 183,
#      'ranking': '183',
#      'bookname': '나인 :천선란 장편소설 ',
#      'authors': '지은이: 천선란',
#      'publisher': '창비',
#      'publication_year': '2021',
#      'isbn13': '9788936438609',
#      'addition_symbol': '03810',
#      'vol': '',
#      'class_no': '813.7',
#      'class_nm': '문학 > 한국문학 > 소설',
#      'loan_count': '105',
#      'bookImageURL': 'https://image.aladin.co.kr/product/28218/87/cover/8936438603_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=6326210'}},
#    {'doc': {'no': 184,
#      'ranking': '183',
#      'bookname': '싯다르타',
#      'authors': '헤르만 헤세 지음;박병덕 옮김',
#      'publisher': '민음사',
#      'publication_year': '2002',
#      'isbn13': '9788937460586',
#      'addition_symbol': '04850',
#      'vol': '58',
#      'class_no': '853',
#      'class_nm': '문학 > 독일문학 > 소설',
#      'loan_count': '105',
#      'bookImageURL': 'http://image.aladin.co.kr/product/32/95/cover/8937460580_3.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=2404471'}},
#    {'doc': {'no': 185,
#      'ranking': '183',
#      'bookname': '어떻게 극단적 소수가 다수를 지배하는가 :우리의 민주주의가 한계에 도달한 이유 ',
#      'authors': '스티븐 레비츠키,박세연 옮김',
#      'publisher': '어크로스(어크로스출판그룹)',
#      'publication_year': '2024',
#      'isbn13': '9791167741509',
#      'addition_symbol': '03340',
#      'vol': '',
#      'class_no': '340.22',
#      'class_nm': '사회과학 > 정치학 > 정치학',
#      'loan_count': '105',
#      'bookImageURL': 'https://image.aladin.co.kr/product/33934/72/cover200/k402930238_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=6875833'}},
#    {'doc': {'no': 186,
#      'ranking': '186',
#      'bookname': '찌그러져도 동그라미입니다 :김창완 에세이 ',
#      'authors': '지은이: 김창완',
#      'publisher': '웅진씽크빅',
#      'publication_year': '2024',
#      'isbn13': '9788901280684',
#      'addition_symbol': '03810',
#      'vol': '',
#      'class_no': '818',
#      'class_nm': '문학 > 한국문학 > 르포르타주 및 기타',
#      'loan_count': '104',
#      'bookImageURL': 'https://image.aladin.co.kr/product/33600/15/cover/890128068x_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=6842827'}},
#    {'doc': {'no': 187,
#      'ranking': '186',
#      'bookname': '대온실 수리 보고서 :김금희 장편소설 ',
#      'authors': '지은이: 김금희',
#      'publisher': '창비',
#      'publication_year': '2024',
#      'isbn13': '9788936439651',
#      'addition_symbol': '03810',
#      'vol': '',
#      'class_no': '813.7',
#      'class_nm': '문학 > 한국문학 > 소설',
#      'loan_count': '104',
#      'bookImageURL': 'https://image.aladin.co.kr/product/34712/24/cover200/8936439650_2.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=6950753'}},
#    {'doc': {'no': 188,
#      'ranking': '186',
#      'bookname': '가녀장의 시대 :이슬아 장편소설 ',
#      'authors': '지은이: 이슬아',
#      'publisher': '문학동네',
#      'publication_year': '2022',
#      'isbn13': '9788954688796',
#      'addition_symbol': '03810',
#      'vol': '',
#      'class_no': '813.7',
#      'class_nm': '문학 > 한국문학 > 소설',
#      'loan_count': '104',
#      'bookImageURL': 'https://image.aladin.co.kr/product/30261/10/cover/8954688799_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=6570833'}},
#    {'doc': {'no': 189,
#      'ranking': '186',
#      'bookname': '어린이라는 세계 :김소영 에세이 ',
#      'authors': '지은이: 김소영',
#      'publisher': '사계절(사계절출판사)',
#      'publication_year': '2020',
#      'isbn13': '9791160946918',
#      'addition_symbol': '03810',
#      'vol': '',
#      'class_no': '818',
#      'class_nm': '문학 > 한국문학 > 르포르타주 및 기타',
#      'loan_count': '104',
#      'bookImageURL': 'https://image.aladin.co.kr/product/25509/75/cover/k132633125_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=5795911'}},
#    {'doc': {'no': 190,
#      'ranking': '186',
#      'bookname': '목소리를 드릴게요 :정세랑 소설집 ',
#      'authors': '지은이: 정세랑',
#      'publisher': '아작',
#      'publication_year': '2020',
#      'isbn13': '9791165300005',
#      'addition_symbol': '03810',
#      'vol': '',
#      'class_no': '813.7',
#      'class_nm': '문학 > 한국문학 > 소설',
#      'loan_count': '104',
#      'bookImageURL': 'https://image.aladin.co.kr/product/22246/11/cover/k842636722_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=5549987'}},
#    {'doc': {'no': 191,
#      'ranking': '186',
#      'bookname': '파친코 :이민진 장편소설 ',
#      'authors': '지은이: 이민진 ;옮긴이: 신승미',
#      'publisher': '인플루엔셜',
#      'publication_year': '2022',
#      'isbn13': '9791168340541',
#      'addition_symbol': '04840',
#      'vol': '2',
#      'class_no': '843.6',
#      'class_nm': '문학 > 영미문학 > 소설',
#      'loan_count': '104',
#      'bookImageURL': 'https://image.aladin.co.kr/product/29496/41/cover/k192838537_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=6540730'}},
#    {'doc': {'no': 192,
#      'ranking': '192',
#      'bookname': '부자의 그릇 :돈을 다루는 능력을 키우는 법 ',
#      'authors': '이즈미 마사토 지음 ;김윤수 옮김',
#      'publisher': '다산북스',
#      'publication_year': '2020',
#      'isbn13': '9791130633619',
#      'addition_symbol': '13320',
#      'vol': '',
#      'class_no': '327.04',
#      'class_nm': '사회과학 > 경제학 > 금융',
#      'loan_count': '103',
#      'bookImageURL': 'https://image.aladin.co.kr/product/25815/98/cover/k002736337_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=5834137'}},
#    {'doc': {'no': 193,
#      'ranking': '192',
#      'bookname': '퓨처 셀프 :현재와 미래가 달라지는 놀라운 혁명 ',
#      'authors': '벤저민 하디 지음 ;최은아 옮김',
#      'publisher': '상상스퀘어',
#      'publication_year': '2023',
#      'isbn13': '9791192389325',
#      'addition_symbol': '03320',
#      'vol': '',
#      'class_no': '325.211',
#      'class_nm': '사회과학 > 경제학 > 경영관리',
#      'loan_count': '103',
#      'bookImageURL': 'https://image.aladin.co.kr/product/32354/81/cover/k342935366_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=6754748'}},
#    {'doc': {'no': 194,
#      'ranking': '194',
#      'bookname': '파과 :구병모 장편소설 ',
#      'authors': '지은이: 구병모',
#      'publisher': '자음과모음',
#      'publication_year': '2013',
#      'isbn13': '9788957077740',
#      'addition_symbol': '03810',
#      'vol': '',
#      'class_no': '813.7',
#      'class_nm': '문학 > 한국문학 > 소설',
#      'loan_count': '102',
#      'bookImageURL': 'https://bookthumb-phinf.pstatic.net/cover/072/689/07268920.jpg?type=m1&udate=20150801',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=1962669'}},
#    {'doc': {'no': 195,
#      'ranking': '194',
#      'bookname': '내면소통 =삶의 변화를 가져오는 마음근력 훈련/Inner communication',
#      'authors': '김주환 지음',
#      'publisher': '인플루엔셜',
#      'publication_year': '2023',
#      'isbn13': '9791168340855',
#      'addition_symbol': '03400',
#      'vol': '',
#      'class_no': '189.1',
#      'class_nm': '철학 > 심리학 > 응용심리학 일반',
#      'loan_count': '102',
#      'bookImageURL': 'https://image.aladin.co.kr/product/31189/93/cover/k412831855_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=6645408'}},
#    {'doc': {'no': 196,
#      'ranking': '194',
#      'bookname': '당신의 인생이 왜 힘들지 않아야 한다고 생각하십니까 :쇼펜하우어 아포리즘 ',
#      'authors': '아르투어 쇼펜하우어 지음 ;김욱 편역',
#      'publisher': '콘텐츠그룹 포레스트',
#      'publication_year': '2023',
#      'isbn13': '9791192625553',
#      'addition_symbol': '03100',
#      'vol': '',
#      'class_no': '165.47',
#      'class_nm': '철학 > 서양철학 > 독일, 오스트리아철학',
#      'loan_count': '102',
#      'bookImageURL': 'https://image.aladin.co.kr/product/31863/3/cover/k132833423_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=6708577'}},
#    {'doc': {'no': 197,
#      'ranking': '197',
#      'bookname': '노랑무늬영원 :한강 소설집 ',
#      'authors': '지은이: 한강',
#      'publisher': '문학과지성사',
#      'publication_year': '2018',
#      'isbn13': '9788932034836',
#      'addition_symbol': '03810',
#      'vol': '',
#      'class_no': '813.62',
#      'class_nm': '문학 > 한국문학 > 소설',
#      'loan_count': '101',
#      'bookImageURL': 'https://bookthumb-phinf.pstatic.net/cover/141/354/14135437.jpg?type=m1&udate=20181107',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=5242212'}},
#    {'doc': {'no': 198,
#      'ranking': '197',
#      'bookname': '겨울 방학 :최진영 소설 ',
#      'authors': '지은이: 최진영',
#      'publisher': '민음사',
#      'publication_year': '2019',
#      'isbn13': '9788937479779',
#      'addition_symbol': '03810',
#      'vol': '',
#      'class_no': '813.7',
#      'class_nm': '문학 > 한국문학 > 소설',
#      'loan_count': '101',
#      'bookImageURL': 'https://image.aladin.co.kr/product/21354/34/cover/893747977x_2.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=5514835'}},
#    {'doc': {'no': 199,
#      'ranking': '197',
#      'bookname': '삼체 =The three body ',
#      'authors': '류츠신 지음 ;허유영 옮김',
#      'publisher': '자음과모음',
#      'publication_year': '2020',
#      'isbn13': '9788954442701',
#      'addition_symbol': '04820',
#      'vol': '2',
#      'class_no': '823.7',
#      'class_nm': '문학 > 중국문학 > 소설',
#      'loan_count': '101',
#      'bookImageURL': 'https://image.aladin.co.kr/product/28912/66/cover/8954442706_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=5708403'}},
#    {'doc': {'no': 200,
#      'ranking': '197',
#      'bookname': '검은 사슴 :한강 장편소설 ',
#      'authors': '지은이: 한강',
#      'publisher': '문학동네',
#      'publication_year': '2017',
#      'isbn13': '9788954648905',
#      'addition_symbol': '04810',
#      'vol': '',
#      'class_no': '813.62',
#      'class_nm': '문학 > 한국문학 > 소설',
#      'loan_count': '101',
#      'bookImageURL': 'https://bookthumb-phinf.pstatic.net/cover/128/974/12897428.jpg?type=m1&udate=20180104',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=3675815'}}]}}

# %%
books = []
for d in data['response']['docs']:
  books.append(d['doc'])

# %%
books
# Out:
# [{'no': 1,
#   'ranking': '1',
#   'bookname': '소년이 온다 :한강 장편소설 ',
#   'authors': '지은이: 한강',
#   'publisher': '창비',
#   'publication_year': '2014',
#   'isbn13': '9788936434120',
#   'addition_symbol': '03810',
#   'vol': '',
#   'class_no': '813.62',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'loan_count': '560',
#   'bookImageURL': 'http://image.aladin.co.kr/product/4086/97/cover/8936434128_2.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=2037399'},
#  {'no': 2,
#   'ranking': '2',
#   'bookname': '물고기는 존재하지 않는다 :상실, 사랑 그리고 숨어 있는 삶의 질서에 관한 이야기 ',
#   'authors': '룰루 밀러 지음 ;정지인 옮김',
#   'publisher': '곰출판',
#   'publication_year': '2021',
#   'isbn13': '9791189327156',
#   'addition_symbol': '03400',
#   'vol': '',
#   'class_no': '490.99',
#   'class_nm': '자연과학 > 동물학 > 동물학',
#   'loan_count': '465',
#   'bookImageURL': 'https://image.aladin.co.kr/product/28465/73/cover/k092835920_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=6360937'},
#  {'no': 3,
#   'ranking': '3',
#   'bookname': '모순 :양귀자 장편소설 ',
#   'authors': '지은이: 양귀자',
#   'publisher': '쓰다',
#   'publication_year': '2013',
#   'isbn13': '9788998441012',
#   'addition_symbol': '03810',
#   'vol': '',
#   'class_no': '813.62',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'loan_count': '422',
#   'bookImageURL': 'https://bookthumb-phinf.pstatic.net/cover/071/902/07190270.jpg?type=m1&udate=20170801',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=1938053'},
#  {'no': 4,
#   'ranking': '4',
#   'bookname': '작별하지 않는다 :한강 장편소설 ',
#   'authors': '지은이: 한강',
#   'publisher': '문학동네',
#   'publication_year': '2021',
#   'isbn13': '9788954682152',
#   'addition_symbol': '03810',
#   'vol': '',
#   'class_no': '813.62',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'loan_count': '421',
#   'bookImageURL': 'https://image.aladin.co.kr/product/27877/5/cover/8954682154_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=6086446'},
#  {'no': 5,
#   'ranking': '5',
#   'bookname': '지구 끝의 온실 :김초엽 장편소설 ',
#   'authors': '지은이: 김초엽',
#   'publisher': 'Giant Books(자이언트북스)',
#   'publication_year': '2021',
#   'isbn13': '9791191824001',
#   'addition_symbol': '03810',
#   'vol': '',
#   'class_no': '813.7',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'loan_count': '416',
#   'bookImageURL': 'https://image.aladin.co.kr/product/27692/63/cover/k082733434_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=6065686'},
#  {'no': 6,
#   'ranking': '6',
#   'bookname': '채식주의자:한강 연작소설',
#   'authors': '한강',
#   'publisher': '창비',
#   'publication_year': '2007',
#   'isbn13': '9788936433598',
#   'addition_symbol': '03810',
#   'vol': '',
#   'class_no': '813.6',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'loan_count': '399',
#   'bookImageURL': 'https://bookthumb-phinf.pstatic.net/cover/033/094/03309417.jpg?type=m1&udate=20180609',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=2155671'},
#  {'no': 7,
#   'ranking': '7',
#   'bookname': '나는 소망한다 내게 금지된 것을 :양귀자 장편소설 ',
#   'authors': '지은이: 양귀자',
#   'publisher': '쓰다',
#   'publication_year': '2019',
#   'isbn13': '9788998441074',
#   'addition_symbol': '03810',
#   'vol': '',
#   'class_no': '813.62',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'loan_count': '374',
#   'bookImageURL': 'https://image.aladin.co.kr/product/18936/52/cover/8998441071_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=5395822'},
#  {'no': 8,
#   'ranking': '8',
#   'bookname': '홍학의 자리 :정해연 장편소설 ',
#   'authors': '지은이: 정해연',
#   'publisher': '문학동네',
#   'publication_year': '2021',
#   'isbn13': '9788954681155',
#   'addition_symbol': '03810',
#   'vol': '',
#   'class_no': '813.7',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'loan_count': '355',
#   'bookImageURL': 'https://image.aladin.co.kr/product/27587/94/cover/8954681158_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=6050062'},
#  {'no': 9,
#   'ranking': '9',
#   'bookname': '종의 기원 =정유정 장편소설 /The origin of species ',
#   'authors': '지은이: 정유정',
#   'publisher': '은행나무',
#   'publication_year': '2016',
#   'isbn13': '9788956609959',
#   'addition_symbol': '03810',
#   'vol': '',
#   'class_no': '813.7',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'loan_count': '354',
#   'bookImageURL': 'http://image.aladin.co.kr/product/7492/9/cover/8956609950_2.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=3151708'},
#  {'no': 10,
#   'ranking': '10',
#   'bookname': '천 개의 파랑 :천선란 장편소설 ',
#   'authors': '지은이: 천선란',
#   'publisher': '허블',
#   'publication_year': '2020',
#   'isbn13': '9791190090261',
#   'addition_symbol': '03810',
#   'vol': '',
#   'class_no': '813.7',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'loan_count': '346',
#   'bookImageURL': 'https://image.aladin.co.kr/product/24895/69/cover/k882632470_2.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=5738747'},
#  {'no': 11,
#   'ranking': '11',
#   'bookname': '대도시의 사랑법 :박상영 연작소설 ',
#   'authors': '지은이: 박상영',
#   'publisher': '창비',
#   'publication_year': '2019',
#   'isbn13': '9788936437978',
#   'addition_symbol': '03810',
#   'vol': '',
#   'class_no': '813.7',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'loan_count': '342',
#   'bookImageURL': 'https://image.aladin.co.kr/product/19543/91/cover/8936437976_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=5435897'},
#  {'no': 12,
#   'ranking': '12',
#   'bookname': '불편한 편의점 :김호연 장편소설 ',
#   'authors': '지은이: 김호연',
#   'publisher': '나무옆의자',
#   'publication_year': '2021',
#   'isbn13': '9791161571188',
#   'addition_symbol': '03810',
#   'vol': '',
#   'class_no': '813.7',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'loan_count': '324',
#   'bookImageURL': 'https://image.aladin.co.kr/product/26942/84/cover/k582730818_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=5962217'},
#  {'no': 13,
#   'ranking': '13',
#   'bookname': '밝은 밤 :최은영 장편소설 ',
#   'authors': '지은이: 최은영',
#   'publisher': '문학동네',
#   'publication_year': '2021',
#   'isbn13': '9788954681179',
#   'addition_symbol': '03810',
#   'vol': '',
#   'class_no': '813.7',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'loan_count': '312',
#   'bookImageURL': 'https://image.aladin.co.kr/product/27541/91/cover/8954681174_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=6045915'},
#  {'no': 14,
#   'ranking': '14',
#   'bookname': '바깥은 여름 :김애란 소설 ',
#   'authors': '지은이: 김애란',
#   'publisher': '문학동네',
#   'publication_year': '2017',
#   'isbn13': '9788954646079',
#   'addition_symbol': '03810',
#   'vol': '',
#   'class_no': '813.7',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'loan_count': '304',
#   'bookImageURL': 'http://image.aladin.co.kr/product/15533/81/cover/k852533629_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=3451595'},
#  {'no': 15,
#   'ranking': '15',
#   'bookname': '지구에서 한아뿐 :정세랑 장편소설 ',
#   'authors': '지은이: 정세랑',
#   'publisher': '난다',
#   'publication_year': '2019',
#   'isbn13': '9791188862290',
#   'addition_symbol': '03810',
#   'vol': '',
#   'class_no': '813.7',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'loan_count': '299',
#   'bookImageURL': 'https://image.aladin.co.kr/product/19804/82/cover/k072635131_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=5446546'},
#  {'no': 16,
#   'ranking': '16',
#   'bookname': '우리가 빛의 속도로 갈 수 없다면 :김초엽 소설 ',
#   'authors': '지은이: 김초엽',
#   'publisher': '허블',
#   'publication_year': '2019',
#   'isbn13': '9791190090018',
#   'addition_symbol': '03810',
#   'vol': '',
#   'class_no': '813.7',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'loan_count': '290',
#   'bookImageURL': 'https://image.aladin.co.kr/product/19359/16/cover/s972635417_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=5430429'},
#  {'no': 17,
#   'ranking': '17',
#   'bookname': '도둑맞은 집중력 :집중력 위기의 시대, 삶의 주도권을 되찾는 법 ',
#   'authors': '요한 하리 지음 ;김하현 옮김',
#   'publisher': '어크로스(어크로스출판그룹)',
#   'publication_year': '2023',
#   'isbn13': '9791167740984',
#   'addition_symbol': '03180',
#   'vol': '',
#   'class_no': '181.27',
#   'class_nm': '철학 > 심리학 > 각론',
#   'loan_count': '288',
#   'bookImageURL': 'https://image.aladin.co.kr/product/31559/97/cover/k682832859_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=6682845'},
#  {'no': 18,
#   'ranking': '18',
#   'bookname': '칵테일, 러브, 좀비 ',
#   'authors': '지은이: 조예은',
#   'publisher': '안전가옥',
#   'publication_year': '2020',
#   'isbn13': '9791190174756',
#   'addition_symbol': '03810',
#   'vol': '',
#   'class_no': '813.7',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'loan_count': '287',
#   'bookImageURL': 'https://image.aladin.co.kr/product/23736/85/cover/k692639764_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=5650149'},
#  {'no': 19,
#   'ranking': '19',
#   'bookname': '채식주의자 :한강 장편소설 ',
#   'authors': '지은이: 한강',
#   'publisher': '창비',
#   'publication_year': '2022',
#   'isbn13': '9788936434595',
#   'addition_symbol': '03810',
#   'vol': '',
#   'class_no': '813.62',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'loan_count': '285',
#   'bookImageURL': 'https://image.aladin.co.kr/product/29137/2/cover/8936434594_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=6428779'},
#  {'no': 20,
#   'ranking': '20',
#   'bookname': '달러구트 꿈 백화점 :이미예 장편소설',
#   'authors': '지은이: 이미예',
#   'publisher': '팩토리나인',
#   'publication_year': '2020',
#   'isbn13': '9791165341909',
#   'addition_symbol': '03810',
#   'vol': '',
#   'class_no': '813.7',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'loan_count': '282',
#   'bookImageURL': 'https://image.aladin.co.kr/product/24512/70/cover/k392630952_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=5707051'},
#  {'no': 21,
#   'ranking': '21',
#   'bookname': '돈은 좋지만 재테크는 겁나는 너에게 ',
#   'authors': '뿅글이 지음',
#   'publisher': '첨단',
#   'publication_year': '2023',
#   'isbn13': '9788960306134',
#   'addition_symbol': '03320',
#   'vol': '',
#   'class_no': '327.04',
#   'class_nm': '사회과학 > 경제학 > 금융',
#   'loan_count': '274',
#   'bookImageURL': 'https://image.aladin.co.kr/product/30921/24/cover/8960306134_2.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=6627400'},
#  {'no': 22,
#   'ranking': '22',
#   'bookname': '아주 희미한 빛으로도 :최은영 소설 ',
#   'authors': '지은이: 최은영',
#   'publisher': '문학동네',
#   'publication_year': '2023',
#   'isbn13': '9788954695053',
#   'addition_symbol': '03810',
#   'vol': '',
#   'class_no': '813.7',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'loan_count': '271',
#   'bookImageURL': 'https://image.aladin.co.kr/product/32129/40/cover/8954695051_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=6738257'},
#  {'no': 23,
#   'ranking': '23',
#   'bookname': '시선으로부터, :정세랑 장편소설 ',
#   'authors': '지은이: 정세랑',
#   'publisher': '문학동네',
#   'publication_year': '2020',
#   'isbn13': '9788954672214',
#   'addition_symbol': '03810',
#   'vol': '',
#   'class_no': '813.7',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'loan_count': '265',
#   'bookImageURL': 'https://image.aladin.co.kr/product/24131/37/cover/8954672213_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=5674475'},
#  {'no': 24,
#   'ranking': '24',
#   'bookname': '희랍어 시간 :한강 장편소설 ',
#   'authors': '지은이: 한강',
#   'publisher': '문학동네',
#   'publication_year': '2011',
#   'isbn13': '9788954616515',
#   'addition_symbol': '03810',
#   'vol': '',
#   'class_no': '813.62',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'loan_count': '248',
#   'bookImageURL': 'https://bookthumb-phinf.pstatic.net/cover/067/707/06770742.jpg?type=m1&udate=20170801',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=1207905'},
#  {'no': 25,
#   'ranking': '25',
#   'bookname': '돌이킬 수 있는 =문목하 장편소설 /Eversible ',
#   'authors': '지은이: 문목하',
#   'publisher': '아작',
#   'publication_year': '2018',
#   'isbn13': '9791189015381',
#   'addition_symbol': '03810',
#   'vol': '',
#   'class_no': '813.7',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'loan_count': '243',
#   'bookImageURL': 'https://image.aladin.co.kr/product/17531/63/cover/k062534304_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=5253241'},
#  {'no': 26,
#   'ranking': '25',
#   'bookname': '내가 한 말을 내가 오해하지 않기로 함 ',
#   'authors': '지은이: 문상훈',
#   'publisher': '위너스북',
#   'publication_year': '2024',
#   'isbn13': '9791189352745',
#   'addition_symbol': '03810',
#   'vol': '',
#   'class_no': '818',
#   'class_nm': '문학 > 한국문학 > 르포르타주 및 기타',
#   'loan_count': '243',
#   'bookImageURL': 'https://image.aladin.co.kr/product/33037/31/cover/k882937586_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=6806344'},
#  {'no': 27,
#   'ranking': '27',
#   'bookname': '구의 증명 :최진영 소설 ',
#   'authors': '지은이: 최진영',
#   'publisher': '은행나무',
#   'publication_year': '2015',
#   'isbn13': '9788956608556',
#   'addition_symbol': '03810',
#   'vol': '',
#   'class_no': '813.7',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'loan_count': '242',
#   'bookImageURL': 'http://image.aladin.co.kr/product/5527/50/cover/8956608555_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=2619618'},
#  {'no': 28,
#   'ranking': '28',
#   'bookname': '급류 :정대건 장편소설 ',
#   'authors': '지은이: 정대건',
#   'publisher': '민음사',
#   'publication_year': '2022',
#   'isbn13': '9788937473401',
#   'addition_symbol': '04810',
#   'vol': '',
#   'class_no': '813.7',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'loan_count': '240',
#   'bookImageURL': 'https://image.aladin.co.kr/product/30769/24/cover/8937473402_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=6614564'},
#  {'no': 29,
#   'ranking': '29',
#   'bookname': '프로젝트 헤일메리 ',
#   'authors': '앤디 위어 지음 ;강동혁 옮김',
#   'publisher': 'RHK(알에이치코리아)',
#   'publication_year': '2021',
#   'isbn13': '9788925588735',
#   'addition_symbol': '04840',
#   'vol': '',
#   'class_no': '843.6',
#   'class_nm': '문학 > 영미문학 > 소설',
#   'loan_count': '238',
#   'bookImageURL': 'https://image.aladin.co.kr/product/27045/43/cover/8925588730_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=5969086'},
#  {'no': 30,
#   'ranking': '30',
#   'bookname': '이처럼 사소한 것들 :클레어 키건 소설 ',
#   'authors': '지은이: 클레어 키건 ;옮긴이: 홍한별',
#   'publisher': '다산북스',
#   'publication_year': '2023',
#   'isbn13': '9791130646381',
#   'addition_symbol': '03840',
#   'vol': '',
#   'class_no': '843.6',
#   'class_nm': '문학 > 영미문학 > 소설',
#   'loan_count': '231',
#   'bookImageURL': 'https://shopping-phinf.pstatic.net/main_4390280/43902803626.20231108182642.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=6791651'},
#  {'no': 31,
#   'ranking': '30',
#   'bookname': '나는 왜 남들보다 쉽게 지칠까 :무던해 보이지만 누구보다 예민한 HSP를 위한 심리학 ',
#   'authors': '최재훈 지음',
#   'publisher': '서스테인',
#   'publication_year': '2024',
#   'isbn13': '9791193388075',
#   'addition_symbol': '03180',
#   'vol': '',
#   'class_no': '182.12',
#   'class_nm': '철학 > 심리학 > 차이심리학',
#   'loan_count': '231',
#   'bookImageURL': 'https://image.aladin.co.kr/product/34214/60/cover200/k482931035_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=6896698'},
#  {'no': 32,
#   'ranking': '32',
#   'bookname': '흰 :한강 소설 ',
#   'authors': '지은이: 한강',
#   'publisher': '문학동네',
#   'publication_year': '2018',
#   'isbn13': '9788954651134',
#   'addition_symbol': '03810',
#   'vol': '',
#   'class_no': '813.62',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'loan_count': '230',
#   'bookImageURL': 'http://image.aladin.co.kr/product/14322/3/cover/8954651135_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=3746119'},
#  {'no': 33,
#   'ranking': '32',
#   'bookname': '(EBS 다큐프라임) 자본주의 ',
#   'authors': 'EBS MEDIA 기획 ;EBS <자본주의> 제작팀 지음',
#   'publisher': '가나문화콘텐츠',
#   'publication_year': '2013',
#   'isbn13': '9788957365793',
#   'addition_symbol': '03320',
#   'vol': '',
#   'class_no': '322.01',
#   'class_nm': '사회과학 > 경제학 > 경제정책',
#   'loan_count': '230',
#   'bookImageURL': 'https://bookthumb-phinf.pstatic.net/cover/073/148/07314866.jpg?type=m1&udate=20170801',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=1975179'},
#  {'no': 34,
#   'ranking': '34',
#   'bookname': '(The) money book :잘 살아갈 우리를 위한 금융생활 안내서 ',
#   'authors': '토스 엮음',
#   'publisher': '비바리퍼블리카',
#   'publication_year': '2024',
#   'isbn13': '9791198686114',
#   'addition_symbol': '03320',
#   'vol': '',
#   'class_no': '327.04',
#   'class_nm': '사회과학 > 경제학 > 금융',
#   'loan_count': '226',
#   'bookImageURL': 'https://image.aladin.co.kr/product/34009/78/cover200/k772931867_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=6880703'},
#  {'no': 35,
#   'ranking': '35',
#   'bookname': '완전한 행복 :정유정 장편소설 ',
#   'authors': '지은이: 정유정',
#   'publisher': '은행나무',
#   'publication_year': '2021',
#   'isbn13': '9791167370280',
#   'addition_symbol': '03810',
#   'vol': '',
#   'class_no': '813.7',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'loan_count': '225',
#   'bookImageURL': 'https://image.aladin.co.kr/product/27225/29/cover/k432732398_2.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=5987427'},
#  {'no': 36,
#   'ranking': '36',
#   'bookname': '파과 :구병모 장편소설 ',
#   'authors': '지은이: 구병모',
#   'publisher': '위즈덤하우스 미디어그룹',
#   'publication_year': '2018',
#   'isbn13': '9791162203620',
#   'addition_symbol': '03810',
#   'vol': '',
#   'class_no': '813.7',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'loan_count': '223',
#   'bookImageURL': 'http://image.aladin.co.kr/product/14224/40/cover/k872532537_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=3742540'},
#  {'no': 37,
#   'ranking': '37',
#   'bookname': '단 한 사람 :최진영 장편소설 ',
#   'authors': '지은이: 최진영',
#   'publisher': '한겨레엔',
#   'publication_year': '2023',
#   'isbn13': '9791160405750',
#   'addition_symbol': '03810',
#   'vol': '',
#   'class_no': '813.7',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'loan_count': '214',
#   'bookImageURL': 'https://image.aladin.co.kr/product/32496/81/cover/k382935719_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=6764215'},
#  {'no': 38,
#   'ranking': '38',
#   'bookname': '트로피컬 나이트 =조예은 소설집 /Tropical night ',
#   'authors': '지은이: 조예은',
#   'publisher': '한겨레엔',
#   'publication_year': '2022',
#   'isbn13': '9791160408331',
#   'addition_symbol': '03810',
#   'vol': '',
#   'class_no': '813.7',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'loan_count': '213',
#   'bookImageURL': 'https://image.aladin.co.kr/product/29946/7/cover/k962838741_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=6541800'},
#  {'no': 39,
#   'ranking': '38',
#   'bookname': '불편한 편의점 :김호연 장편소설',
#   'authors': '지은이: 김호연',
#   'publisher': '나무옆의자',
#   'publication_year': '2022',
#   'isbn13': '9791161571379',
#   'addition_symbol': '03810',
#   'vol': '2',
#   'class_no': '813.7',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'loan_count': '213',
#   'bookImageURL': 'https://image.aladin.co.kr/product/29858/98/cover/k432838027_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=6529613'},
#  {'no': 40,
#   'ranking': '40',
#   'bookname': '돈의 속성 :최상위 부자가 말하는 돈에 대한 모든 것 ',
#   'authors': '지은이: 김승호',
#   'publisher': 'Snowfox(스노우폭스북스)',
#   'publication_year': '2020',
#   'isbn13': '9791188331796',
#   'addition_symbol': '03320',
#   'vol': '',
#   'class_no': '327.04',
#   'class_nm': '사회과학 > 경제학 > 금융',
#   'loan_count': '212',
#   'bookImageURL': 'https://image.aladin.co.kr/product/24191/64/cover/k562639753_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=5678862'},
#  {'no': 41,
#   'ranking': '41',
#   'bookname': '나미야 잡화점의 기적 :히가시노 게이고 장편소설 ',
#   'authors': '지은이: 히가시노 게이고 ;옮긴이: 양윤옥',
#   'publisher': '현대문학',
#   'publication_year': '2012',
#   'isbn13': '9788972756194',
#   'addition_symbol': '03830',
#   'vol': '',
#   'class_no': '833.6',
#   'class_nm': '문학 > 일본문학 > 소설',
#   'loan_count': '209',
#   'bookImageURL': 'http://image.aladin.co.kr/product/15848/6/cover/k622533431_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=1902173'},
#  {'no': 42,
#   'ranking': '42',
#   'bookname': '스노볼 드라이브 :조예은 장편소설 ',
#   'authors': '지은이: 조예은',
#   'publisher': '민음사',
#   'publication_year': '2021',
#   'isbn13': '9788937473319',
#   'addition_symbol': '04810',
#   'vol': '',
#   'class_no': '813.7',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'loan_count': '207',
#   'bookImageURL': 'https://bookthumb-phinf.pstatic.net/cover/180/045/18004516.jpg?type=m1&udate=20210218',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=5882740'},
#  {'no': 43,
#   'ranking': '43',
#   'bookname': '연남동 빙굴빙굴 빨래방 :김지윤 장편소설 ',
#   'authors': '지은이: 김지윤',
#   'publisher': '팩토리나인',
#   'publication_year': '2023',
#   'isbn13': '9791165347734',
#   'addition_symbol': '03810',
#   'vol': '',
#   'class_no': '813.7',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'loan_count': '204',
#   'bookImageURL': 'https://image.aladin.co.kr/product/32131/89/cover/k742834302_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=6738246'},
#  {'no': 44,
#   'ranking': '44',
#   'bookname': '부자 아빠 가난한 아빠 :20주년 특별 기념판 ',
#   'authors': '지은이: 로버트 기요사키 ;옮긴이: 안진환',
#   'publisher': '민음인',
#   'publication_year': '2018',
#   'isbn13': '9791158883591',
#   'addition_symbol': '03320',
#   'vol': '',
#   'class_no': '327.04',
#   'class_nm': '사회과학 > 경제학 > 금융',
#   'loan_count': '202',
#   'bookImageURL': 'http://image.aladin.co.kr/product/13492/56/cover/k162532501_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=3701374'},
#  {'no': 45,
#   'ranking': '44',
#   'bookname': '세이노의 가르침 :피보다 진하게 살아라 ',
#   'authors': '세이노 지음',
#   'publisher': '데이원',
#   'publication_year': '2023',
#   'isbn13': '9791168473690',
#   'addition_symbol': '03190',
#   'vol': '',
#   'class_no': '325.211',
#   'class_nm': '사회과학 > 경제학 > 경영관리',
#   'loan_count': '202',
#   'bookImageURL': 'https://image.aladin.co.kr/product/30929/51/cover/k732831392_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=6628064'},
#  {'no': 46,
#   'ranking': '46',
#   'bookname': '입속 지느러미 :조예은 장편소설 ',
#   'authors': '지은이: 조예은',
#   'publisher': '한겨레엔',
#   'publication_year': '2024',
#   'isbn13': '9791172130633',
#   'addition_symbol': '04810',
#   'vol': '',
#   'class_no': '813.7',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'loan_count': '201',
#   'bookImageURL': 'https://image.aladin.co.kr/product/34002/54/cover200/k462930652_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=6879532'},
#  {'no': 47,
#   'ranking': '47',
#   'bookname': '아이가 없는 집 ',
#   'authors': '지은이: 알렉스 안도릴 ;옮긴이: 유혜인',
#   'publisher': '필름',
#   'publication_year': '2024',
#   'isbn13': '9791193262184',
#   'addition_symbol': '03850',
#   'vol': '',
#   'class_no': '859.7',
#   'class_nm': '문학 > 독일문학 > 기타 게르만 문학',
#   'loan_count': '200',
#   'bookImageURL': 'https://image.aladin.co.kr/product/34117/59/cover200/k962931994_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=6890223'},
#  {'no': 48,
#   'ranking': '48',
#   'bookname': '아주 작은 습관의 힘 :최고의 변화는 어떻게 만들어지는가 ',
#   'authors': '제임스 클리어 지음 ;이한이 옮김',
#   'publisher': '비즈니스북스',
#   'publication_year': '2019',
#   'isbn13': '9791162540640',
#   'addition_symbol': '03190',
#   'vol': '',
#   'class_no': '181.845',
#   'class_nm': '철학 > 심리학 > 각론',
#   'loan_count': '199',
#   'bookImageURL': 'https://image.aladin.co.kr/product/18228/51/cover/k832534441_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=5368180'},
#  {'no': 49,
#   'ranking': '49',
#   'bookname': '귀신들의 땅 :천쓰홍 장편 소설 ',
#   'authors': '지은이: 천쓰홍 ;옮긴이: 김태성',
#   'publisher': '민음사',
#   'publication_year': '2023',
#   'isbn13': '9788937454820',
#   'addition_symbol': '03820',
#   'vol': '',
#   'class_no': '823.7',
#   'class_nm': '문학 > 중국문학 > 소설',
#   'loan_count': '196',
#   'bookImageURL': 'https://image.aladin.co.kr/product/33119/32/cover/8937454823_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=6811808'},
#  {'no': 50,
#   'ranking': '49',
#   'bookname': '달러구트 꿈 백화점 :이미예 장편소설',
#   'authors': '지은이: 이미예',
#   'publisher': '팩토리나인',
#   'publication_year': '2021',
#   'isbn13': '9791165343729',
#   'addition_symbol': '03810',
#   'vol': '2',
#   'class_no': '813.7',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'loan_count': '196',
#   'bookImageURL': 'https://image.aladin.co.kr/product/27587/47/cover/k962733015_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=6049391'},
#  {'no': 51,
#   'ranking': '51',
#   'bookname': '내게 무해한 사람 :최은영 소설 ',
#   'authors': '지은이: 최은영',
#   'publisher': '문학동네',
#   'publication_year': '2018',
#   'isbn13': '9788954651820',
#   'addition_symbol': '03810',
#   'vol': '',
#   'class_no': '813.7',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'loan_count': '193',
#   'bookImageURL': 'https://image.aladin.co.kr/product/15133/51/cover/8954651828_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=3774162'},
#  {'no': 52,
#   'ranking': '51',
#   'bookname': '오렌지와 빵칼 =청예 장편소설 /Orange and bread knife ',
#   'authors': '지은이: 청예',
#   'publisher': '허블',
#   'publication_year': '2024',
#   'isbn13': '9791193078259',
#   'addition_symbol': '03810',
#   'vol': '',
#   'class_no': '813.7',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'loan_count': '193',
#   'bookImageURL': 'https://image.aladin.co.kr/product/34259/77/cover200/k852932962_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=6901042'},
#  {'no': 53,
#   'ranking': '53',
#   'bookname': '이끼숲 :천선란 연작소설 ',
#   'authors': '지은이: 천선란 ;일러스트: 점선면',
#   'publisher': '자이언트북스',
#   'publication_year': '2023',
#   'isbn13': '9791191824216',
#   'addition_symbol': '03810',
#   'vol': '',
#   'class_no': '813.7',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'loan_count': '192',
#   'bookImageURL': 'https://image.aladin.co.kr/product/31568/81/cover/k672832652_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=6682814'},
#  {'no': 54,
#   'ranking': '54',
#   'bookname': '7년의 밤 :정유정 장편소설 ',
#   'authors': '지은이: 정유정',
#   'publisher': '은행나무',
#   'publication_year': '2011',
#   'isbn13': '9788956604992',
#   'addition_symbol': '03810',
#   'vol': '',
#   'class_no': '813.7',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'loan_count': '189',
#   'bookImageURL': 'http://image.aladin.co.kr/product/14712/55/cover/k202532053_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=1153285'},
#  {'no': 55,
#   'ranking': '55',
#   'bookname': '삼체 =The three body ',
#   'authors': '류츠신 지음 ;허유영 옮김',
#   'publisher': '자음과모음',
#   'publication_year': '2020',
#   'isbn13': '9788954442695',
#   'addition_symbol': '04820',
#   'vol': '1',
#   'class_no': '823.7',
#   'class_nm': '문학 > 중국문학 > 소설',
#   'loan_count': '188',
#   'bookImageURL': 'https://image.aladin.co.kr/product/28912/65/cover/8954442692_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=5708402'},
#  {'no': 56,
#   'ranking': '55',
#   'bookname': '그의 운명에 대한 아주 개인적인 생각 ',
#   'authors': '지은이: 유시민',
#   'publisher': '아름다운사람들',
#   'publication_year': '2024',
#   'isbn13': '9788965138068',
#   'addition_symbol': '03300',
#   'vol': '',
#   'class_no': '340.911',
#   'class_nm': '사회과학 > 정치학 > 정치학',
#   'loan_count': '188',
#   'bookImageURL': 'https://image.aladin.co.kr/product/34121/16/cover200/s812931190_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=6890222'},
#  {'no': 57,
#   'ranking': '57',
#   'bookname': '아몬드손원평 장편소설',
#   'authors': '손원평',
#   'publisher': '창비',
#   'publication_year': '2017',
#   'isbn13': '9788936434267',
#   'addition_symbol': '03810',
#   'vol': '',
#   'class_no': '813.7',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'loan_count': '187',
#   'bookImageURL': 'http://image.aladin.co.kr/product/16839/4/cover/k492534773_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=3423096'},
#  {'no': 58,
#   'ranking': '57',
#   'bookname': '아버지의 해방일지 :정지아 장편소설 ',
#   'authors': '지은이: 정지아',
#   'publisher': '창비',
#   'publication_year': '2022',
#   'isbn13': '9788936438838',
#   'addition_symbol': '03810',
#   'vol': '',
#   'class_no': '813.62',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'loan_count': '187',
#   'bookImageURL': 'https://image.aladin.co.kr/product/30048/51/cover/8936438832_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=6551957'},
#  {'no': 59,
#   'ranking': '59',
#   'bookname': '더 좋은 삶을 위한 철학 ',
#   'authors': '지은이: 마이클 슈어 ;옮긴이: 염지선',
#   'publisher': '김영사',
#   'publication_year': '2023',
#   'isbn13': '9788934965909',
#   'addition_symbol': '03190',
#   'vol': '',
#   'class_no': '190',
#   'class_nm': '철학 > 윤리학, 도덕철학 > 윤리학, 도덕철학',
#   'loan_count': '186',
#   'bookImageURL': 'https://image.aladin.co.kr/product/31132/45/cover/8934965908_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=6643878'},
#  {'no': 60,
#   'ranking': '59',
#   'bookname': '미드나잇 라이브러리 ',
#   'authors': '매트 헤이그 지음 ;노진선 옮김',
#   'publisher': '인플루엔셜',
#   'publication_year': '2021',
#   'isbn13': '9791191056556',
#   'addition_symbol': '03840',
#   'vol': '',
#   'class_no': '843.6',
#   'class_nm': '문학 > 영미문학 > 소설',
#   'loan_count': '186',
#   'bookImageURL': 'https://image.aladin.co.kr/product/26987/37/cover/k962730610_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=5965665'},
#  {'no': 61,
#   'ranking': '59',
#   'bookname': '탕비실 :이미예 소설 ',
#   'authors': '지은이: 이미예',
#   'publisher': '오팬하우스',
#   'publication_year': '2024',
#   'isbn13': '9791198809940',
#   'addition_symbol': '03810',
#   'vol': '',
#   'class_no': '813.7',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'loan_count': '186',
#   'bookImageURL': 'https://image.aladin.co.kr/product/34193/41/cover200/k602931315_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=6894621'},
#  {'no': 62,
#   'ranking': '62',
#   'bookname': '흰 :한강 소설 ',
#   'authors': '지은이: 한강',
#   'publisher': '문학동네',
#   'publication_year': '2016',
#   'isbn13': '9788954640718',
#   'addition_symbol': '03810',
#   'vol': '',
#   'class_no': '813.62',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'loan_count': '181',
#   'bookImageURL': 'http://image.aladin.co.kr/product/8466/1/cover/k712535369_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=3153205'},
#  {'no': 63,
#   'ranking': '62',
#   'bookname': '파견자들 :김초엽 장편소설 ',
#   'authors': '지은이: 김초엽',
#   'publisher': '퍼블리온',
#   'publication_year': '2023',
#   'isbn13': '9791191587524',
#   'addition_symbol': '03810',
#   'vol': '',
#   'class_no': '813.7',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'loan_count': '181',
#   'bookImageURL': 'https://image.aladin.co.kr/product/32591/29/cover/k352935549_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=6772199'},
#  {'no': 64,
#   'ranking': '64',
#   'bookname': '서랍에 저녁을 넣어 두었다 :한강 시집 ',
#   'authors': '지은이: 한강',
#   'publisher': '문학과지성사',
#   'publication_year': '2013',
#   'isbn13': '9788932024639',
#   'addition_symbol': '03810',
#   'vol': '',
#   'class_no': '811.62',
#   'class_nm': '문학 > 한국문학 > 시',
#   'loan_count': '180',
#   'bookImageURL': 'http://image.aladin.co.kr/product/3335/59/cover/8932024634_3.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=1991954'},
#  {'no': 65,
#   'ranking': '65',
#   'bookname': '저주토끼 (리커버)',
#   'authors': '정보라 (지은이)',
#   'publisher': '아작',
#   'publication_year': '2022',
#   'isbn13': '9791166686665',
#   'addition_symbol': '',
#   'vol': '',
#   'class_no': '',
#   'class_nm': ' >  > ',
#   'loan_count': '178',
#   'bookImageURL': 'https://image.aladin.co.kr/product/29084/68/cover/k122836656_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=6424905'},
#  {'no': 66,
#   'ranking': '66',
#   'bookname': '왜 나는 너를 사랑하는가',
#   'authors': '알랭 드 보통 [지음];정영목 옮김',
#   'publisher': '청미래',
#   'publication_year': '2007',
#   'isbn13': '9788986836240',
#   'addition_symbol': '03840',
#   'vol': '',
#   'class_no': '843',
#   'class_nm': '문학 > 영미문학 > 소설',
#   'loan_count': '177',
#   'bookImageURL': 'https://bookthumb-phinf.pstatic.net/cover/030/257/03025716.jpg?type=m1&udate=20180227',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=2130072'},
#  {'no': 67,
#   'ranking': '67',
#   'bookname': '해가 지는 곳으로 :최진영 장편소설 ',
#   'authors': '지은이: 최진영',
#   'publisher': '민음사',
#   'publication_year': '2017',
#   'isbn13': '9788937473166',
#   'addition_symbol': '04810',
#   'vol': '',
#   'class_no': '813.7',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'loan_count': '175',
#   'bookImageURL': 'http://image.aladin.co.kr/product/11281/18/cover/893747316x_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=3468676'},
#  {'no': 68,
#   'ranking': '67',
#   'bookname': '이중 하나는 거짓말 :김애란 장편소설 ',
#   'authors': '지은이: 김애란',
#   'publisher': '문학동네',
#   'publication_year': '2024',
#   'isbn13': '9791141601300',
#   'addition_symbol': '03810',
#   'vol': '',
#   'class_no': '813.7',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'loan_count': '175',
#   'bookImageURL': 'https://image.aladin.co.kr/product/34474/76/cover200/k292932634_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=6933234'},
#  {'no': 69,
#   'ranking': '67',
#   'bookname': '돈의 심리학 :당신은 왜 부자가 되지 못했는가 ',
#   'authors': '모건 하우절 지음 ;이지연 옮김',
#   'publisher': '인플루엔셜',
#   'publication_year': '2021',
#   'isbn13': '9791191056372',
#   'addition_symbol': '03320',
#   'vol': '',
#   'class_no': '327.04',
#   'class_nm': '사회과학 > 경제학 > 금융',
#   'loan_count': '175',
#   'bookImageURL': 'https://image.aladin.co.kr/product/25967/85/cover/k412737326_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=5846583'},
#  {'no': 70,
#   'ranking': '70',
#   'bookname': '다정한 것이 살아남는다 ',
#   'authors': '지은이: 브라이언 헤어,옮긴이: 이민아',
#   'publisher': '디플롯',
#   'publication_year': '2021',
#   'isbn13': '9791197413025',
#   'addition_symbol': '03400',
#   'vol': '',
#   'class_no': '182.4',
#   'class_nm': '철학 > 심리학 > 차이심리학',
#   'loan_count': '174',
#   'bookImageURL': 'https://image.aladin.co.kr/product/27608/83/cover/k722733028_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=6060921'},
#  {'no': 71,
#   'ranking': '71',
#   'bookname': '크리스마스 타일 :김금희 연작소설 ',
#   'authors': '지은이: 김금희',
#   'publisher': '창비',
#   'publication_year': '2022',
#   'isbn13': '9788936438890',
#   'addition_symbol': '03810',
#   'vol': '',
#   'class_no': '813.7',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'loan_count': '173',
#   'bookImageURL': 'https://image.aladin.co.kr/product/30520/41/cover/8936438891_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=6595121'},
#  {'no': 72,
#   'ranking': '71',
#   'bookname': '적산가옥의 유령 :조예은 소설 ',
#   'authors': '지은이: 조예은',
#   'publisher': 'H(현대문학)',
#   'publication_year': '2024',
#   'isbn13': '9791167902580',
#   'addition_symbol': '04810',
#   'vol': '',
#   'class_no': '813.7',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'loan_count': '173',
#   'bookImageURL': 'https://image.aladin.co.kr/product/34286/38/cover200/k592932077_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=6905353'},
#  {'no': 73,
#   'ranking': '73',
#   'bookname': '쇼코의 미소 :최은영 소설 ',
#   'authors': '지은이: 최은영',
#   'publisher': '문학동네',
#   'publication_year': '2016',
#   'isbn13': '9788954641630',
#   'addition_symbol': '03810',
#   'vol': '',
#   'class_no': '813.7',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'loan_count': '172',
#   'bookImageURL': 'https://bookthumb-phinf.pstatic.net/cover/107/859/10785953.jpg?type=m1&udate=20180717',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=3190615'},
#  {'no': 74,
#   'ranking': '73',
#   'bookname': '타이탄의 도구들 :1만 시간의 법칙을 깬 거인들의 61가지 전략 ',
#   'authors': '팀 페리스 지음 ;정지현 옮김',
#   'publisher': 'Tornado(토네이도)',
#   'publication_year': '2017',
#   'isbn13': '9791158510619',
#   'addition_symbol': '03190',
#   'vol': '',
#   'class_no': '325.211',
#   'class_nm': '사회과학 > 경제학 > 경영관리',
#   'loan_count': '172',
#   'bookImageURL': 'http://image.aladin.co.kr/product/10590/57/cover/k162530537_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=3423727'},
#  {'no': 75,
#   'ranking': '75',
#   'bookname': '피프티 피플 :정세랑 장편소설 ',
#   'authors': '지은이: 정세랑',
#   'publisher': '창비',
#   'publication_year': '2016',
#   'isbn13': '9788936434243',
#   'addition_symbol': '03810',
#   'vol': '',
#   'class_no': '813.7',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'loan_count': '169',
#   'bookImageURL': 'https://bookthumb-phinf.pstatic.net/cover/113/062/11306271.jpg?type=m1&udate=20180117',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=3391014'},
#  {'no': 76,
#   'ranking': '76',
#   'bookname': '내가 틀릴 수도 있습니다 =숲속의 현자가 전하는 마지막 인생수업 /I may be wrong ',
#   'authors': '비욘 나티코 린데블라드 지음 ;박미경 옮김',
#   'publisher': '다산북스',
#   'publication_year': '2022',
#   'isbn13': '9791130689890',
#   'addition_symbol': '03100',
#   'vol': '',
#   'class_no': '220.4',
#   'class_nm': '종교 > 불교 > 불교',
#   'loan_count': '168',
#   'bookImageURL': 'https://image.aladin.co.kr/product/29269/12/cover/k822837807_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=6445483'},
#  {'no': 77,
#   'ranking': '77',
#   'bookname': '메리골드 마음 세탁소 =윤정은 장편소설 /Marigold mind laundry ',
#   'authors': '글: 윤정은',
#   'publisher': '북로망스',
#   'publication_year': '2023',
#   'isbn13': '9791191891287',
#   'addition_symbol': '03810',
#   'vol': '',
#   'class_no': '813.7',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'loan_count': '167',
#   'bookImageURL': 'https://image.aladin.co.kr/product/31222/5/cover/k562831250_2.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=6648006'},
#  {'no': 78,
#   'ranking': '78',
#   'bookname': '눈부신 안부 :백수린 장편소설 ',
#   'authors': '지은이: 백수린',
#   'publisher': '문학동네',
#   'publication_year': '2023',
#   'isbn13': '9788954699372',
#   'addition_symbol': '03810',
#   'vol': '',
#   'class_no': '813.7',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'loan_count': '166',
#   'bookImageURL': 'https://image.aladin.co.kr/product/31688/62/cover/8954699375_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=6694629'},
#  {'no': 79,
#   'ranking': '79',
#   'bookname': '랑과 나의 사막 :천선란 소설 ',
#   'authors': '지은이: 천선란',
#   'publisher': 'H(현대문학)',
#   'publication_year': '2022',
#   'isbn13': '9791167901354',
#   'addition_symbol': '04810',
#   'vol': '',
#   'class_no': '813.7',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'loan_count': '165',
#   'bookImageURL': 'https://image.aladin.co.kr/product/30395/18/cover/k572830160_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=6580839'},
#  {'no': 80,
#   'ranking': '80',
#   'bookname': '두 사람의 인터내셔널 :김기태 소설 ',
#   'authors': '지은이: 김기태',
#   'publisher': '문학동네',
#   'publication_year': '2024',
#   'isbn13': '9788954697941',
#   'addition_symbol': '03810',
#   'vol': '',
#   'class_no': '813.7',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'loan_count': '163',
#   'bookImageURL': 'https://image.aladin.co.kr/product/33899/7/cover200/8954697941_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=6873522'},
#  {'no': 81,
#   'ranking': '81',
#   'bookname': '가면산장 살인사건 ',
#   'authors': '지은이: 히가시노 게이고 ;옮긴이: 김난주',
#   'publisher': '재인',
#   'publication_year': '2014',
#   'isbn13': '9788990982575',
#   'addition_symbol': '03830',
#   'vol': '',
#   'class_no': '833.6',
#   'class_nm': '문학 > 일본문학 > 소설',
#   'loan_count': '158',
#   'bookImageURL': 'http://image.aladin.co.kr/product/4745/51/cover/899098257x_2.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=2427470'},
#  {'no': 82,
#   'ranking': '82',
#   'bookname': '방금 떠나온 세계 :김초엽 소설집 ',
#   'authors': '지은이: 김초엽',
#   'publisher': '한겨레엔',
#   'publication_year': '2021',
#   'isbn13': '9791160406504',
#   'addition_symbol': '03810',
#   'vol': '',
#   'class_no': '813.7',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'loan_count': '156',
#   'bookImageURL': 'https://image.aladin.co.kr/product/28170/22/cover/k032835560_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=6322276'},
#  {'no': 83,
#   'ranking': '82',
#   'bookname': '시대예보 :핵개인의 시대 =Forecast of the times : era of nuclear individuals ',
#   'authors': '저자: 송길영',
#   'publisher': '교보문고',
#   'publication_year': '2023',
#   'isbn13': '9791170610359',
#   'addition_symbol': '03320',
#   'vol': '',
#   'class_no': '331.544',
#   'class_nm': '사회과학 > 사회학, 사회문제 > 사회학',
#   'loan_count': '156',
#   'bookImageURL': 'https://image.aladin.co.kr/product/32462/56/cover/k942935205_3.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=6761221'},
#  {'no': 84,
#   'ranking': '84',
#   'bookname': '용의자 X의 헌신 ',
#   'authors': '히가시노 게이고 지음 ;양억관 옮김',
#   'publisher': '재인',
#   'publication_year': '2017',
#   'isbn13': '9788990982704',
#   'addition_symbol': '03830',
#   'vol': '',
#   'class_no': '833.6',
#   'class_nm': '문학 > 일본문학 > 소설',
#   'loan_count': '155',
#   'bookImageURL': 'https://bookthumb-phinf.pstatic.net/cover/124/818/12481857.jpg?type=m1&udate=20170914',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=3541024'},
#  {'no': 85,
#   'ranking': '85',
#   'bookname': '도파민네이션 :쾌락 과잉 시대에서 균형 찾기 ',
#   'authors': '애나 렘키 지음 ;김두완 옮김',
#   'publisher': '흐름출판',
#   'publication_year': '2022',
#   'isbn13': '9788965965046',
#   'addition_symbol': '03180',
#   'vol': '',
#   'class_no': '181.71',
#   'class_nm': '철학 > 심리학 > 각론',
#   'loan_count': '154',
#   'bookImageURL': 'https://image.aladin.co.kr/product/29125/5/cover/8965965047_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=6428072'},
#  {'no': 86,
#   'ranking': '85',
#   'bookname': '악마의 계약서는 만기 되지 않는다 :리러하 장편소설 ',
#   'authors': '지은이: 리러하',
#   'publisher': '팩토리나인',
#   'publication_year': '2022',
#   'isbn13': '9791165345839',
#   'addition_symbol': '03810',
#   'vol': '',
#   'class_no': '813.7',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'loan_count': '154',
#   'bookImageURL': 'https://image.aladin.co.kr/product/29885/33/cover/k712838837_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=6535280'},
#  {'no': 87,
#   'ranking': '87',
#   'bookname': '영원한 천국 :정유정 장편소설 ',
#   'authors': '지은이: 정유정',
#   'publisher': '은행나무',
#   'publication_year': '2024',
#   'isbn13': '9791167374561',
#   'addition_symbol': '03810',
#   'vol': '',
#   'class_no': '813.7',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'loan_count': '153',
#   'bookImageURL': 'https://image.aladin.co.kr/product/34499/81/cover200/k712932751_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=6934298'},
#  {'no': 88,
#   'ranking': '88',
#   'bookname': '브람스를 좋아하세요 ',
#   'authors': '프랑수아즈 사강 [지음] ;김남주 옮김',
#   'publisher': '민음사',
#   'publication_year': '2008',
#   'isbn13': '9788937461798',
#   'addition_symbol': '04800',
#   'vol': '179',
#   'class_no': '863',
#   'class_nm': '문학 > 프랑스문학 > 소설',
#   'loan_count': '151',
#   'bookImageURL': 'https://bookthumb-phinf.pstatic.net/cover/045/694/04569434.jpg?type=m1&udate=20130412',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=2374505'},
#  {'no': 89,
#   'ranking': '88',
#   'bookname': '사랑과 결함 :예소연 소설 ',
#   'authors': '지은이: 예소연',
#   'publisher': '문학동네',
#   'publication_year': '2024',
#   'isbn13': '9791141601102',
#   'addition_symbol': '03810',
#   'vol': '',
#   'class_no': '813.7',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'loan_count': '151',
#   'bookImageURL': 'https://image.aladin.co.kr/product/34366/96/cover200/k972932005_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=6922272'},
#  {'no': 90,
#   'ranking': '90',
#   'bookname': '국가란 무엇인가 ',
#   'authors': '유시민 지음',
#   'publisher': '돌베개',
#   'publication_year': '2017',
#   'isbn13': '9788971998014',
#   'addition_symbol': '03340',
#   'vol': '',
#   'class_no': '341',
#   'class_nm': '사회과학 > 정치학 > 국가형태',
#   'loan_count': '150',
#   'bookImageURL': 'http://image.aladin.co.kr/product/10115/84/cover/8971998016_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=3408932'},
#  {'no': 91,
#   'ranking': '90',
#   'bookname': '어서오세요, 휴남동 서점입니다 :황보름 장편소설 ',
#   'authors': '지은이: 황보름',
#   'publisher': '클레이하우스',
#   'publication_year': '2022',
#   'isbn13': '9791197377143',
#   'addition_symbol': '03810',
#   'vol': '',
#   'class_no': '813.7',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'loan_count': '150',
#   'bookImageURL': 'https://image.aladin.co.kr/product/28685/95/cover/k362836265_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=6389692'},
#  {'no': 92,
#   'ranking': '92',
#   'bookname': '눈에 갇힌 외딴 산장에서',
#   'authors': '히가시노 게이고 (지은이), 김난주 (옮긴이)',
#   'publisher': '재인',
#   'publication_year': '2023',
#   'isbn13': '9791192483191',
#   'addition_symbol': '',
#   'vol': '',
#   'class_no': '',
#   'class_nm': ' >  > ',
#   'loan_count': '148',
#   'bookImageURL': 'https://image.aladin.co.kr/product/32089/67/cover/k522834190_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=6734083'},
#  {'no': 93,
#   'ranking': '93',
#   'bookname': '나는 메트로폴리탄 미술관의 경비원입니다 :가장 경이로운 세계 속으로 숨어버린 한 남자의 이야기 ',
#   'authors': '패트릭 브링리 지음 ;조현주 옮김',
#   'publisher': '웅진씽크빅',
#   'publication_year': '2023',
#   'isbn13': '9788901276533',
#   'addition_symbol': '03840',
#   'vol': '',
#   'class_no': '848',
#   'class_nm': '문학 > 영미문학 > 르포르타주 및 기타',
#   'loan_count': '147',
#   'bookImageURL': 'https://image.aladin.co.kr/product/32892/38/cover/8901276534_2.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=6793850'},
#  {'no': 94,
#   'ranking': '93',
#   'bookname': '예루살렘의 아이히만',
#   'authors': '한나 아렌트 지음;김선욱 옮김',
#   'publisher': '한길사',
#   'publication_year': '2006',
#   'isbn13': '9788935656615',
#   'addition_symbol': '94160',
#   'vol': '',
#   'class_no': '909.54',
#   'class_nm': '역사 > 역사 > 세계사, 세계문화사',
#   'loan_count': '147',
#   'bookImageURL': 'https://bookthumb-phinf.pstatic.net/cover/025/276/02527697.jpg?type=m1&udate=20161020',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=2062893'},
#  {'no': 95,
#   'ranking': '93',
#   'bookname': '당신은 결국 무엇이든 해내는 사람 :김상현 에세이 ',
#   'authors': '지은이: 김상현',
#   'publisher': '필름(필름출판사)',
#   'publication_year': '2022',
#   'isbn13': '9791188469994',
#   'addition_symbol': '03810',
#   'vol': '',
#   'class_no': '818',
#   'class_nm': '문학 > 한국문학 > 르포르타주 및 기타',
#   'loan_count': '147',
#   'bookImageURL': 'https://image.aladin.co.kr/product/29234/19/cover/k572837292_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=6441556'},
#  {'no': 96,
#   'ranking': '93',
#   'bookname': '빛이 이끄는 곳으로 =백희성 장편소설 /La ou la lumiere me conduit ',
#   'authors': '지은이: 백희성',
#   'publisher': '책읽어주는남자',
#   'publication_year': '2024',
#   'isbn13': '9791193937198',
#   'addition_symbol': '03810',
#   'vol': '',
#   'class_no': '813.7',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'loan_count': '147',
#   'bookImageURL': 'https://image.aladin.co.kr/product/34449/77/cover200/k052932333_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=6932136'},
#  {'no': 97,
#   'ranking': '97',
#   'bookname': '아가미 :구병모 장편소설 ',
#   'authors': '지은이: 구병모',
#   'publisher': '위즈덤하우스',
#   'publication_year': '2018',
#   'isbn13': '9791162203392',
#   'addition_symbol': '03810',
#   'vol': '',
#   'class_no': '813.7',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'loan_count': '146',
#   'bookImageURL': 'http://image.aladin.co.kr/product/13925/89/cover/k732532525_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=3732414'},
#  {'no': 98,
#   'ranking': '98',
#   'bookname': '참을 수 없는 존재의 가벼움 ',
#   'authors': '지은이: 밀란 쿤데라 ;옮긴이: 이재룡',
#   'publisher': '민음사',
#   'publication_year': '2018',
#   'isbn13': '9788937437564',
#   'addition_symbol': '03860',
#   'vol': '',
#   'class_no': '892.96',
#   'class_nm': '문학 > 기타 제문학 > 인도-유럽계문학',
#   'loan_count': '145',
#   'bookImageURL': 'http://image.aladin.co.kr/product/15251/16/cover/8937437562_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=3788932'},
#  {'no': 99,
#   'ranking': '98',
#   'bookname': 'H마트에서 울다 ',
#   'authors': '미셸 자우너 지음 ;정혜윤 옮김',
#   'publisher': '문학동네',
#   'publication_year': '2022',
#   'isbn13': '9788954683371',
#   'addition_symbol': '03840',
#   'vol': '',
#   'class_no': '848',
#   'class_nm': '문학 > 영미문학 > 르포르타주 및 기타',
#   'loan_count': '145',
#   'bookImageURL': 'https://image.aladin.co.kr/product/28962/10/cover/8954683371_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=6412735'},
#  {'no': 100,
#   'ranking': '98',
#   'bookname': '마흔에 읽는 쇼펜하우어 :마음의 위기를 다스리는 철학 수업 ',
#   'authors': '강용수 지음',
#   'publisher': '유노콘텐츠그룹',
#   'publication_year': '2023',
#   'isbn13': '9791192300818',
#   'addition_symbol': '03160',
#   'vol': '',
#   'class_no': '165.47',
#   'class_nm': '철학 > 서양철학 > 독일, 오스트리아철학',
#   'loan_count': '145',
#   'bookImageURL': 'https://image.aladin.co.kr/product/32361/59/cover/k592935565_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=6754766'},
#  {'no': 101,
#   'ranking': '101',
#   'bookname': '구의 증명',
#   'authors': '최진영 (지은이)',
#   'publisher': '은행나무',
#   'publication_year': '2023',
#   'isbn13': '9791167372864',
#   'addition_symbol': '',
#   'vol': '',
#   'class_no': '',
#   'class_nm': ' >  > ',
#   'loan_count': '144',
#   'bookImageURL': 'https://image.aladin.co.kr/product/31561/46/cover/k782832854_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=6682008'},
#  {'no': 102,
#   'ranking': '102',
#   'bookname': '역행자 :돈·시간·운명으로부터 완전한 자유를 얻는 7단계 인생 공략집 ',
#   'authors': '자청 지음',
#   'publisher': '웅진씽크빅',
#   'publication_year': '2022',
#   'isbn13': '9788901260716',
#   'addition_symbol': '03320',
#   'vol': '',
#   'class_no': '325.211',
#   'class_nm': '사회과학 > 경제학 > 경영관리',
#   'loan_count': '143',
#   'bookImageURL': 'https://image.aladin.co.kr/product/29521/63/cover/8901260719_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=6468069'},
#  {'no': 103,
#   'ranking': '102',
#   'bookname': '오로라 ',
#   'authors': '지은이: 최진영',
#   'publisher': '위즈덤하우스',
#   'publication_year': '2024',
#   'isbn13': '9791168127500',
#   'addition_symbol': '04810',
#   'vol': '',
#   'class_no': '813.7',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'loan_count': '143',
#   'bookImageURL': 'https://image.aladin.co.kr/product/33464/10/cover/k652938849_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=6834576'},
#  {'no': 104,
#   'ranking': '104',
#   'bookname': '작은 땅의 야수들 :김주혜 장편소설 ',
#   'authors': '지은이: 김주혜 ;옮긴이: 박소현',
#   'publisher': '다산북스',
#   'publication_year': '2022',
#   'isbn13': '9791130693927',
#   'addition_symbol': '03840',
#   'vol': '',
#   'class_no': '843.6',
#   'class_nm': '문학 > 영미문학 > 소설',
#   'loan_count': '142',
#   'bookImageURL': 'https://image.aladin.co.kr/product/30213/74/cover/k042839491_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=6567775'},
#  {'no': 105,
#   'ranking': '105',
#   'bookname': '트러스트 :에르난 디아스 장편소설 ',
#   'authors': '지은이: 에르난 디아스 ;옮긴이: 강동혁',
#   'publisher': '문학동네',
#   'publication_year': '2023',
#   'isbn13': '9788954691673',
#   'addition_symbol': '03840',
#   'vol': '',
#   'class_no': '843.6',
#   'class_nm': '문학 > 영미문학 > 소설',
#   'loan_count': '141',
#   'bookImageURL': 'https://image.aladin.co.kr/product/31180/30/cover/8954691676_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=6645288'},
#  {'no': 106,
#   'ranking': '105',
#   'bookname': '파친코 :이민진 장편소설',
#   'authors': '이민진 지음 ;이미정 옮김',
#   'publisher': '문학사상',
#   'publication_year': '2018',
#   'isbn13': '9788970129815',
#   'addition_symbol': '04840',
#   'vol': '1',
#   'class_no': '843.6',
#   'class_nm': '문학 > 영미문학 > 소설',
# ...
#   'publisher': '민음사',
#   'publication_year': '2000',
#   'isbn13': '9788937460449',
#   'addition_symbol': '04850',
#   'vol': '44',
#   'class_no': '853',
#   'class_nm': '문학 > 독일문학 > 소설',
#   'loan_count': '110',
#   'bookImageURL': 'https://bookthumb-phinf.pstatic.net/cover/000/051/00005186.jpg?type=m1&udate=20160509',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=2374415'},
#  {'no': 167,
#   'ranking': '167',
#   'bookname': '여수의 사랑 :한강 소설집 ',
#   'authors': '지은이: 한강',
#   'publisher': '문학과지성사',
#   'publication_year': '2018',
#   'isbn13': '9788932034812',
#   'addition_symbol': '03810',
#   'vol': '',
#   'class_no': '813.62',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'loan_count': '109',
#   'bookImageURL': 'https://bookthumb-phinf.pstatic.net/cover/141/354/14135435.jpg?type=m1&udate=20181107',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=5242214'},
#  {'no': 168,
#   'ranking': '167',
#   'bookname': '심판 ',
#   'authors': '베르나르 베르베르 지음 ;전미연 옮김',
#   'publisher': '열린책들',
#   'publication_year': '2020',
#   'isbn13': '9788932920405',
#   'addition_symbol': '03860',
#   'vol': '',
#   'class_no': '862',
#   'class_nm': '문학 > 프랑스문학 > 희곡',
#   'loan_count': '109',
#   'bookImageURL': 'https://image.aladin.co.kr/product/24919/70/cover/8932920400_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=5738734'},
#  {'no': 169,
#   'ranking': '167',
#   'bookname': '자존감 수업 :하루에 하나, 나를 사랑하게 되는 자존감 회복 훈련 ',
#   'authors': '윤홍균 지음',
#   'publisher': '심플라이프',
#   'publication_year': '2016',
#   'isbn13': '9791186757093',
#   'addition_symbol': '03190',
#   'vol': '',
#   'class_no': '182.1',
#   'class_nm': '철학 > 심리학 > 차이심리학',
#   'loan_count': '109',
#   'bookImageURL': 'http://image.aladin.co.kr/product/8679/31/cover/k372535696_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=3320490'},
#  {'no': 170,
#   'ranking': '167',
#   'bookname': '딸아, 돈 공부 절대 미루지 마라 :돈과 인생에 대한 가장 현실적인 조언 50 ',
#   'authors': '박소연 지음',
#   'publisher': '메이븐',
#   'publication_year': '2023',
#   'isbn13': '9791190538572',
#   'addition_symbol': '03190',
#   'vol': '',
#   'class_no': '327.04',
#   'class_nm': '사회과학 > 경제학 > 금융',
#   'loan_count': '109',
#   'bookImageURL': 'https://image.aladin.co.kr/product/31657/95/cover/k092833678_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=6693602'},
#  {'no': 171,
#   'ranking': '171',
#   'bookname': '비행운 :김애란 소설집 ',
#   'authors': '지은이: 김애란',
#   'publisher': '문학과지성사',
#   'publication_year': '2012',
#   'isbn13': '9788932023151',
#   'addition_symbol': '03810',
#   'vol': '',
#   'class_no': '813.7',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'loan_count': '108',
#   'bookImageURL': 'http://image.aladin.co.kr/product/1801/21/cover/8932023158_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=1855307'},
#  {'no': 172,
#   'ranking': '171',
#   'bookname': '마법소녀 은퇴합니다 :박서련 소설 ',
#   'authors': '지은이: 박서련',
#   'publisher': '창비',
#   'publication_year': '2022',
#   'isbn13': '9788936438739',
#   'addition_symbol': '03810',
#   'vol': '',
#   'class_no': '813.7',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'loan_count': '108',
#   'bookImageURL': 'https://image.aladin.co.kr/product/29250/64/cover/8936438735_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=6442398'},
#  {'no': 173,
#   'ranking': '171',
#   'bookname': '정의란 무엇인가 ',
#   'authors': '지은이: 마이클 샌델 ;옮긴이: 김명철',
#   'publisher': '미래엔',
#   'publication_year': '2014',
#   'isbn13': '9788937834790',
#   'addition_symbol': '03300',
#   'vol': '',
#   'class_no': '193',
#   'class_nm': '철학 > 윤리학, 도덕철학 > 국가 및 정치윤리',
#   'loan_count': '108',
#   'bookImageURL': 'http://image.aladin.co.kr/product/10826/23/cover/k742530554_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=2763903'},
#  {'no': 174,
#   'ranking': '171',
#   'bookname': '거인의 노트 :인생에서 무엇을 보고 어떻게 기록할 것인가 ',
#   'authors': '김익한 지음',
#   'publisher': '다산북스',
#   'publication_year': '2023',
#   'isbn13': '9791130697529',
#   'addition_symbol': '03190',
#   'vol': '',
#   'class_no': '325.211',
#   'class_nm': '사회과학 > 경제학 > 경영관리',
#   'loan_count': '108',
#   'bookImageURL': 'https://shopping-phinf.pstatic.net/main_3830325/38303250624.20230302071138.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=6650346'},
#  {'no': 175,
#   'ranking': '175',
#   'bookname': '이기적 유전자 ',
#   'authors': '리처드 도킨스 지음 ;이상임 옮김',
#   'publisher': '을유문화사',
#   'publication_year': '2018',
#   'isbn13': '9788932473901',
#   'addition_symbol': '03470',
#   'vol': '',
#   'class_no': '491.51',
#   'class_nm': '자연과학 > 동물학 > 일반 동물학',
#   'loan_count': '107',
#   'bookImageURL': 'https://image.aladin.co.kr/product/17048/25/cover/8932473900_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=3921678'},
#  {'no': 176,
#   'ranking': '175',
#   'bookname': '불안 ',
#   'authors': '지은이: 알랭 드 보통 ;정영목 옮김',
#   'publisher': '은행나무',
#   'publication_year': '2012',
#   'isbn13': '9788956605593',
#   'addition_symbol': '03840',
#   'vol': '',
#   'class_no': '332.6',
#   'class_nm': '사회과학 > 사회학, 사회문제 > 사회조직 및 제도',
#   'loan_count': '107',
#   'bookImageURL': 'https://bookthumb-phinf.pstatic.net/cover/067/930/06793081.jpg?type=m1&udate=20171011',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=1226611'},
#  {'no': 177,
#   'ranking': '175',
#   'bookname': '한 스푼의 시간 :구병모 장편소설 ',
#   'authors': '지은이: 구병모',
#   'publisher': '위즈덤하우스',
#   'publication_year': '2016',
#   'isbn13': '9788959130580',
#   'addition_symbol': '03810',
#   'vol': '',
#   'class_no': '813.7',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'loan_count': '107',
#   'bookImageURL': 'http://image.aladin.co.kr/product/9131/24/cover/8959130583_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=3326576'},
#  {'no': 178,
#   'ranking': '175',
#   'bookname': '만조를 기다리며 :우리 숨바꼭질 기억해? ',
#   'authors': '지은이: 조예은',
#   'publisher': '위즈덤하우스',
#   'publication_year': '2023',
#   'isbn13': '9791168127128',
#   'addition_symbol': '04810',
#   'vol': '',
#   'class_no': '813.7',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'loan_count': '107',
#   'bookImageURL': 'https://image.aladin.co.kr/product/31681/11/cover/k062833889_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=6693802'},
#  {'no': 179,
#   'ranking': '179',
#   'bookname': '언러키 스타트업 :정지음 시트콤소설 ',
#   'authors': '지은이: 정지음',
#   'publisher': '민음사',
#   'publication_year': '2022',
#   'isbn13': '9788937427343',
#   'addition_symbol': '03810',
#   'vol': '',
#   'class_no': '813.7',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'loan_count': '106',
#   'bookImageURL': 'https://image.aladin.co.kr/product/30275/85/cover/8937427346_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=6572502'},
#  {'no': 180,
#   'ranking': '179',
#   'bookname': '나의 한국현대사 :1959-2020 ',
#   'authors': '유시민 지음',
#   'publisher': '돌베개',
#   'publication_year': '2021',
#   'isbn13': '9788971999080',
#   'addition_symbol': '03910',
#   'vol': '',
#   'class_no': '911.07',
#   'class_nm': '역사 > 아시아(아세아) > 한국',
#   'loan_count': '106',
#   'bookImageURL': 'https://image.aladin.co.kr/product/26075/76/cover/897199908x_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=5849773'},
#  {'no': 181,
#   'ranking': '179',
#   'bookname': '희망 :양귀자 장편소설 ',
#   'authors': '지은이: 양귀자',
#   'publisher': '쓰다',
#   'publication_year': '2020',
#   'isbn13': '9788998441081',
#   'addition_symbol': '03810',
#   'vol': '',
#   'class_no': '813.62',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'loan_count': '106',
#   'bookImageURL': 'https://image.aladin.co.kr/product/24415/15/cover/899844108x_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=5701868'},
#  {'no': 182,
#   'ranking': '179',
#   'bookname': '바다가 들리는 편의점 ',
#   'authors': '마치다 소노코 지음 ;황국영 옮김',
#   'publisher': '바이포엠 스튜디오',
#   'publication_year': '2023',
#   'isbn13': '9791192579504',
#   'addition_symbol': '03830',
#   'vol': '',
#   'class_no': '833.6',
#   'class_nm': '문학 > 일본문학 > 소설',
#   'loan_count': '106',
#   'bookImageURL': 'https://shopping-phinf.pstatic.net/main_3878746/38787460621.20230320201202.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=6661646'},
#  {'no': 183,
#   'ranking': '183',
#   'bookname': '나인 :천선란 장편소설 ',
#   'authors': '지은이: 천선란',
#   'publisher': '창비',
#   'publication_year': '2021',
#   'isbn13': '9788936438609',
#   'addition_symbol': '03810',
#   'vol': '',
#   'class_no': '813.7',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'loan_count': '105',
#   'bookImageURL': 'https://image.aladin.co.kr/product/28218/87/cover/8936438603_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=6326210'},
#  {'no': 184,
#   'ranking': '183',
#   'bookname': '싯다르타',
#   'authors': '헤르만 헤세 지음;박병덕 옮김',
#   'publisher': '민음사',
#   'publication_year': '2002',
#   'isbn13': '9788937460586',
#   'addition_symbol': '04850',
#   'vol': '58',
#   'class_no': '853',
#   'class_nm': '문학 > 독일문학 > 소설',
#   'loan_count': '105',
#   'bookImageURL': 'http://image.aladin.co.kr/product/32/95/cover/8937460580_3.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=2404471'},
#  {'no': 185,
#   'ranking': '183',
#   'bookname': '어떻게 극단적 소수가 다수를 지배하는가 :우리의 민주주의가 한계에 도달한 이유 ',
#   'authors': '스티븐 레비츠키,박세연 옮김',
#   'publisher': '어크로스(어크로스출판그룹)',
#   'publication_year': '2024',
#   'isbn13': '9791167741509',
#   'addition_symbol': '03340',
#   'vol': '',
#   'class_no': '340.22',
#   'class_nm': '사회과학 > 정치학 > 정치학',
#   'loan_count': '105',
#   'bookImageURL': 'https://image.aladin.co.kr/product/33934/72/cover200/k402930238_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=6875833'},
#  {'no': 186,
#   'ranking': '186',
#   'bookname': '찌그러져도 동그라미입니다 :김창완 에세이 ',
#   'authors': '지은이: 김창완',
#   'publisher': '웅진씽크빅',
#   'publication_year': '2024',
#   'isbn13': '9788901280684',
#   'addition_symbol': '03810',
#   'vol': '',
#   'class_no': '818',
#   'class_nm': '문학 > 한국문학 > 르포르타주 및 기타',
#   'loan_count': '104',
#   'bookImageURL': 'https://image.aladin.co.kr/product/33600/15/cover/890128068x_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=6842827'},
#  {'no': 187,
#   'ranking': '186',
#   'bookname': '대온실 수리 보고서 :김금희 장편소설 ',
#   'authors': '지은이: 김금희',
#   'publisher': '창비',
#   'publication_year': '2024',
#   'isbn13': '9788936439651',
#   'addition_symbol': '03810',
#   'vol': '',
#   'class_no': '813.7',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'loan_count': '104',
#   'bookImageURL': 'https://image.aladin.co.kr/product/34712/24/cover200/8936439650_2.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=6950753'},
#  {'no': 188,
#   'ranking': '186',
#   'bookname': '가녀장의 시대 :이슬아 장편소설 ',
#   'authors': '지은이: 이슬아',
#   'publisher': '문학동네',
#   'publication_year': '2022',
#   'isbn13': '9788954688796',
#   'addition_symbol': '03810',
#   'vol': '',
#   'class_no': '813.7',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'loan_count': '104',
#   'bookImageURL': 'https://image.aladin.co.kr/product/30261/10/cover/8954688799_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=6570833'},
#  {'no': 189,
#   'ranking': '186',
#   'bookname': '어린이라는 세계 :김소영 에세이 ',
#   'authors': '지은이: 김소영',
#   'publisher': '사계절(사계절출판사)',
#   'publication_year': '2020',
#   'isbn13': '9791160946918',
#   'addition_symbol': '03810',
#   'vol': '',
#   'class_no': '818',
#   'class_nm': '문학 > 한국문학 > 르포르타주 및 기타',
#   'loan_count': '104',
#   'bookImageURL': 'https://image.aladin.co.kr/product/25509/75/cover/k132633125_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=5795911'},
#  {'no': 190,
#   'ranking': '186',
#   'bookname': '목소리를 드릴게요 :정세랑 소설집 ',
#   'authors': '지은이: 정세랑',
#   'publisher': '아작',
#   'publication_year': '2020',
#   'isbn13': '9791165300005',
#   'addition_symbol': '03810',
#   'vol': '',
#   'class_no': '813.7',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'loan_count': '104',
#   'bookImageURL': 'https://image.aladin.co.kr/product/22246/11/cover/k842636722_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=5549987'},
#  {'no': 191,
#   'ranking': '186',
#   'bookname': '파친코 :이민진 장편소설 ',
#   'authors': '지은이: 이민진 ;옮긴이: 신승미',
#   'publisher': '인플루엔셜',
#   'publication_year': '2022',
#   'isbn13': '9791168340541',
#   'addition_symbol': '04840',
#   'vol': '2',
#   'class_no': '843.6',
#   'class_nm': '문학 > 영미문학 > 소설',
#   'loan_count': '104',
#   'bookImageURL': 'https://image.aladin.co.kr/product/29496/41/cover/k192838537_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=6540730'},
#  {'no': 192,
#   'ranking': '192',
#   'bookname': '부자의 그릇 :돈을 다루는 능력을 키우는 법 ',
#   'authors': '이즈미 마사토 지음 ;김윤수 옮김',
#   'publisher': '다산북스',
#   'publication_year': '2020',
#   'isbn13': '9791130633619',
#   'addition_symbol': '13320',
#   'vol': '',
#   'class_no': '327.04',
#   'class_nm': '사회과학 > 경제학 > 금융',
#   'loan_count': '103',
#   'bookImageURL': 'https://image.aladin.co.kr/product/25815/98/cover/k002736337_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=5834137'},
#  {'no': 193,
#   'ranking': '192',
#   'bookname': '퓨처 셀프 :현재와 미래가 달라지는 놀라운 혁명 ',
#   'authors': '벤저민 하디 지음 ;최은아 옮김',
#   'publisher': '상상스퀘어',
#   'publication_year': '2023',
#   'isbn13': '9791192389325',
#   'addition_symbol': '03320',
#   'vol': '',
#   'class_no': '325.211',
#   'class_nm': '사회과학 > 경제학 > 경영관리',
#   'loan_count': '103',
#   'bookImageURL': 'https://image.aladin.co.kr/product/32354/81/cover/k342935366_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=6754748'},
#  {'no': 194,
#   'ranking': '194',
#   'bookname': '파과 :구병모 장편소설 ',
#   'authors': '지은이: 구병모',
#   'publisher': '자음과모음',
#   'publication_year': '2013',
#   'isbn13': '9788957077740',
#   'addition_symbol': '03810',
#   'vol': '',
#   'class_no': '813.7',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'loan_count': '102',
#   'bookImageURL': 'https://bookthumb-phinf.pstatic.net/cover/072/689/07268920.jpg?type=m1&udate=20150801',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=1962669'},
#  {'no': 195,
#   'ranking': '194',
#   'bookname': '내면소통 =삶의 변화를 가져오는 마음근력 훈련/Inner communication',
#   'authors': '김주환 지음',
#   'publisher': '인플루엔셜',
#   'publication_year': '2023',
#   'isbn13': '9791168340855',
#   'addition_symbol': '03400',
#   'vol': '',
#   'class_no': '189.1',
#   'class_nm': '철학 > 심리학 > 응용심리학 일반',
#   'loan_count': '102',
#   'bookImageURL': 'https://image.aladin.co.kr/product/31189/93/cover/k412831855_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=6645408'},
#  {'no': 196,
#   'ranking': '194',
#   'bookname': '당신의 인생이 왜 힘들지 않아야 한다고 생각하십니까 :쇼펜하우어 아포리즘 ',
#   'authors': '아르투어 쇼펜하우어 지음 ;김욱 편역',
#   'publisher': '콘텐츠그룹 포레스트',
#   'publication_year': '2023',
#   'isbn13': '9791192625553',
#   'addition_symbol': '03100',
#   'vol': '',
#   'class_no': '165.47',
#   'class_nm': '철학 > 서양철학 > 독일, 오스트리아철학',
#   'loan_count': '102',
#   'bookImageURL': 'https://image.aladin.co.kr/product/31863/3/cover/k132833423_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=6708577'},
#  {'no': 197,
#   'ranking': '197',
#   'bookname': '노랑무늬영원 :한강 소설집 ',
#   'authors': '지은이: 한강',
#   'publisher': '문학과지성사',
#   'publication_year': '2018',
#   'isbn13': '9788932034836',
#   'addition_symbol': '03810',
#   'vol': '',
#   'class_no': '813.62',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'loan_count': '101',
#   'bookImageURL': 'https://bookthumb-phinf.pstatic.net/cover/141/354/14135437.jpg?type=m1&udate=20181107',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=5242212'},
#  {'no': 198,
#   'ranking': '197',
#   'bookname': '겨울 방학 :최진영 소설 ',
#   'authors': '지은이: 최진영',
#   'publisher': '민음사',
#   'publication_year': '2019',
#   'isbn13': '9788937479779',
#   'addition_symbol': '03810',
#   'vol': '',
#   'class_no': '813.7',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'loan_count': '101',
#   'bookImageURL': 'https://image.aladin.co.kr/product/21354/34/cover/893747977x_2.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=5514835'},
#  {'no': 199,
#   'ranking': '197',
#   'bookname': '삼체 =The three body ',
#   'authors': '류츠신 지음 ;허유영 옮김',
#   'publisher': '자음과모음',
#   'publication_year': '2020',
#   'isbn13': '9788954442701',
#   'addition_symbol': '04820',
#   'vol': '2',
#   'class_no': '823.7',
#   'class_nm': '문학 > 중국문학 > 소설',
#   'loan_count': '101',
#   'bookImageURL': 'https://image.aladin.co.kr/product/28912/66/cover/8954442706_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=5708403'},
#  {'no': 200,
#   'ranking': '197',
#   'bookname': '검은 사슴 :한강 장편소설 ',
#   'authors': '지은이: 한강',
#   'publisher': '문학동네',
#   'publication_year': '2017',
#   'isbn13': '9788954648905',
#   'addition_symbol': '04810',
#   'vol': '',
#   'class_no': '813.62',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'loan_count': '101',
#   'bookImageURL': 'https://bookthumb-phinf.pstatic.net/cover/128/974/12897428.jpg?type=m1&udate=20180104',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=3675815'}]

# %%
books_df = pd.DataFrame(books)
books_df
# Out:
#       no ranking                                        bookname  \
# 0      1       1                                소년이 온다 :한강 장편소설
# 1      2       2  물고기는 존재하지 않는다 :상실, 사랑 그리고 숨어 있는 삶의 질서에 관한 이야기
# 2      3       3                                   모순 :양귀자 장편소설
# 3      4       4                              작별하지 않는다 :한강 장편소설
# 4      5       5                             지구 끝의 온실 :김초엽 장편소설
# ..   ...     ...                                             ...
# 195  196     194       당신의 인생이 왜 힘들지 않아야 한다고 생각하십니까 :쇼펜하우어 아포리즘
# 196  197     197                                 노랑무늬영원 :한강 소설집
# 197  198     197                                  겨울 방학 :최진영 소설
# 198  199     197                             삼체 =The three body
# 199  200     197                                 검은 사슴 :한강 장편소설
#
#                   authors            publisher publication_year  \
# 0                 지은이: 한강                   창비             2014
# 1        룰루 밀러 지음 ;정지인 옮김                  곰출판             2021
# 2                지은이: 양귀자                   쓰다             2013
# 3                 지은이: 한강                 문학동네             2021
# 4                지은이: 김초엽  Giant Books(자이언트북스)             2021
# ..                    ...                  ...              ...
# 195  아르투어 쇼펜하우어 지음 ;김욱 편역           콘텐츠그룹 포레스트             2023
# 196               지은이: 한강               문학과지성사             2018
# 197              지은이: 최진영                  민음사             2019
# 198        류츠신 지음 ;허유영 옮김                자음과모음             2020
# 199               지은이: 한강                 문학동네             2017
#
#             isbn13 addition_symbol vol class_no                 class_nm  \
# 0    9788936434120           03810       813.62           문학 > 한국문학 > 소설
# 1    9791189327156           03400       490.99         자연과학 > 동물학 > 동물학
# 2    9788998441012           03810       813.62           문학 > 한국문학 > 소설
# 3    9788954682152           03810       813.62           문학 > 한국문학 > 소설
# 4    9791191824001           03810        813.7           문학 > 한국문학 > 소설
# ..             ...             ...  ..      ...                      ...
# 195  9791192625553           03100       165.47  철학 > 서양철학 > 독일, 오스트리아철학
# 196  9788932034836           03810       813.62           문학 > 한국문학 > 소설
# 197  9788937479779           03810        813.7           문학 > 한국문학 > 소설
# 198  9788954442701           04820   2    823.7           문학 > 중국문학 > 소설
# 199  9788954648905           04810       813.62           문학 > 한국문학 > 소설
#
#     loan_count                                       bookImageURL  \
# 0          560  http://image.aladin.co.kr/product/4086/97/cove...
# 1          465  https://image.aladin.co.kr/product/28465/73/co...
# 2          422  https://bookthumb-phinf.pstatic.net/cover/071/...
# 3          421  https://image.aladin.co.kr/product/27877/5/cov...
# 4          416  https://image.aladin.co.kr/product/27692/63/co...
# ..         ...                                                ...
# 195        102  https://image.aladin.co.kr/product/31863/3/cov...
# 196        101  https://bookthumb-phinf.pstatic.net/cover/141/...
# 197        101  https://image.aladin.co.kr/product/21354/34/co...
# 198        101  https://image.aladin.co.kr/product/28912/66/co...
# 199        101  https://bookthumb-phinf.pstatic.net/cover/128/...
#
#                                     bookDtlUrl
# 0    https://data4library.kr/bookV?seq=2037399
# 1    https://data4library.kr/bookV?seq=6360937
# 2    https://data4library.kr/bookV?seq=1938053
# 3    https://data4library.kr/bookV?seq=6086446
# 4    https://data4library.kr/bookV?seq=6065686
# ..                                         ...
# 195  https://data4library.kr/bookV?seq=6708577
# 196  https://data4library.kr/bookV?seq=5242212
# 197  https://data4library.kr/bookV?seq=5514835
# 198  https://data4library.kr/bookV?seq=5708403
# 199  https://data4library.kr/bookV?seq=3675815
#
# [200 rows x 14 columns]

# %%
books_df.to_json('20s_best_book.json')

# %% [markdown]
# # 마무리
# ***API***(Application Programming Interface)는 프로그램 간 데이터를 전달하기 위해 정한 규칙.
#
# |함수/메서드|기능|
# |:--|--:|
# |json.dumps()|파이썬 객체를 JSON 문자열로 변환한다.|
# |json.loads()|JSON 문자열을 파이썬 객체로 변환한다.|
# |pandas.read_json()|JSON 문자열을 판다스 시리즈나 데이터프레임으로 변환한다.|
# |xml.etree.ElementTree.fromstring()|XML 문자열을 분석하여 xml.etree.ElementTree 클래스 객체를 반환한다.|
# |xml.etree.ElementTree.Element.findtext()|지정한 태그 이름과 맞는 첫 번째 자식 엘리먼트의 텍스트를 반환한다.|
# |xml.etree.ElementTree.Element.findall()|지정한 태그 이름과 맞는 모든 자식 엘리먼트를 반환한다.|
# |requests.get()|HTTP GET 방식으로 URL을 호출하고 requests.Response 객체를 반환한다.|
# |requests.Response.json()|응답받은 JSON 문자열을 파이썬 객체로 변환하여 반환한다.|
